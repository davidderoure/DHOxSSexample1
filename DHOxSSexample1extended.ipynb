# %% [markdown]
# DHOxSS Computational thinking Example 1 - Concordance

# %% [markdown]
# The Natural Language Toolkit (NLTK) provides a library of text processing tools and access to some corpora - for more info see https://www.nltk.org/

# %% [markdown]
# The following lines of python code simply set up the library for use - these do not need to be changed

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('gutenberg')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/davidderoure/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/davidderoure/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/davidderoure/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/davidderoure/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/davidderoure/nltk_data...
# True

# %% [markdown]
# Here we create a small sample of text to experiment with

# %%
txt="""
It is a truth universally acknowledged, that a single man in possession of a good fortune must
be in want of a wife. However little known the feelings or views of such a man may be on his
first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding
families, that he is considered as the rightful property of some one or other of their daughters."""

# %% [markdown]
# Now we ask python to show us this text (if there are line breaks they appear as \n)

# %%
txt
# Out:
# '\nIt is a truth universally acknowledged, that a single man in possession of a good fortune must\nbe in want of a wife. However little known the feelings or views of such a man may be on his\nfirst entering a neighbourhood, this truth is so well fixed in the minds of the surrounding\nfamilies, that he is considered as the rightful property of some one or other of their daughters.'

# %% [markdown]
# We use the NLTK sentence tokenizer to identify the individual sentences - it gives us a list of sentences, using the list syntax [ item, item, item, ... ]

# %%
sents = sent_tokenize(txt)
sents
# Out:
# ['\nIt is a truth universally acknowledged, that a single man in possession of a good fortune must\nbe in want of a wife.',
#  'However little known the feelings or views of such a man may be on his\nfirst entering a neighbourhood, this truth is so well fixed in the minds of the surrounding\nfamilies, that he is considered as the rightful property of some one or other of their daughters.']

# %% [markdown]
# Check the length of the list of sentences

# %%
len(sents)
# Out:
# 2

# %% [markdown]
# Print on the screen each of the sentences in the list

# %%
for s in sents:
    print(s)
# Out:
# It is a truth universally acknowledged, that a single man in possession of a good fortune must
# be in want of a wife.
# However little known the feelings or views of such a man may be on his
# first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding
# families, that he is considered as the rightful property of some one or other of their daughters.

# %% [markdown]
# Now print the lengths of each sentence - these are numbers of characters

# %%
for s in sents:
    print(len(s))
# Out:
# 117
# 260

# %% [markdown]
# Now we tokenize into words instead of sentences

# %%
words = word_tokenize(txt)
print(words)
# Out:
# ['It', 'is', 'a', 'truth', 'universally', 'acknowledged', ',', 'that', 'a', 'single', 'man', 'in', 'possession', 'of', 'a', 'good', 'fortune', 'must', 'be', 'in', 'want', 'of', 'a', 'wife', '.', 'However', 'little', 'known', 'the', 'feelings', 'or', 'views', 'of', 'such', 'a', 'man', 'may', 'be', 'on', 'his', 'first', 'entering', 'a', 'neighbourhood', ',', 'this', 'truth', 'is', 'so', 'well', 'fixed', 'in', 'the', 'minds', 'of', 'the', 'surrounding', 'families', ',', 'that', 'he', 'is', 'considered', 'as', 'the', 'rightful', 'property', 'of', 'some', 'one', 'or', 'other', 'of', 'their', 'daughters', '.']

# %%
len(words)
# Out:
# 76

# %% [markdown]
# To demonstrate a simple automated task which the computer can perform easily, here we use the NLTK library to identify parts of speech

# %%
wordpos=nltk.pos_tag(words)
wordpos
# Out:
# [('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('truth', 'NN'),
#  ('universally', 'RB'),
#  ('acknowledged', 'VBD'),
#  (',', ','),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('single', 'JJ'),
#  ('man', 'NN'),
#  ('in', 'IN'),
#  ('possession', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('fortune', 'NN'),
#  ('must', 'MD'),
#  ('be', 'VB'),
#  ('in', 'IN'),
#  ('want', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('wife', 'NN'),
#  ('.', '.'),
#  ('However', 'RB'),
#  ('little', 'JJ'),
#  ('known', 'VBN'),
#  ('the', 'DT'),
#  ('feelings', 'NNS'),
#  ('or', 'CC'),
#  ('views', 'NNS'),
#  ('of', 'IN'),
#  ('such', 'JJ'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('on', 'IN'),
#  ('his', 'PRP$'),
#  ('first', 'JJ'),
#  ('entering', 'VBG'),
#  ('a', 'DT'),
#  ('neighbourhood', 'NN'),
#  (',', ','),
#  ('this', 'DT'),
#  ('truth', 'NN'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('well', 'RB'),
#  ('fixed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('minds', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('surrounding', 'VBG'),
#  ('families', 'NNS'),
#  (',', ','),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('considered', 'VBN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('rightful', 'JJ'),
#  ('property', 'NN'),
#  ('of', 'IN'),
#  ('some', 'DT'),
#  ('one', 'CD'),
#  ('or', 'CC'),
#  ('other', 'JJ'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('daughters', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# This is an alternative way of printing out all the items in a list

# %%
print(*wordpos)
# Out:
# ('It', 'PRP') ('is', 'VBZ') ('a', 'DT') ('truth', 'NN') ('universally', 'RB') ('acknowledged', 'VBD') (',', ',') ('that', 'IN') ('a', 'DT') ('single', 'JJ') ('man', 'NN') ('in', 'IN') ('possession', 'NN') ('of', 'IN') ('a', 'DT') ('good', 'JJ') ('fortune', 'NN') ('must', 'MD') ('be', 'VB') ('in', 'IN') ('want', 'NN') ('of', 'IN') ('a', 'DT') ('wife', 'NN') ('.', '.') ('However', 'RB') ('little', 'JJ') ('known', 'VBN') ('the', 'DT') ('feelings', 'NNS') ('or', 'CC') ('views', 'NNS') ('of', 'IN') ('such', 'JJ') ('a', 'DT') ('man', 'NN') ('may', 'MD') ('be', 'VB') ('on', 'IN') ('his', 'PRP$') ('first', 'JJ') ('entering', 'VBG') ('a', 'DT') ('neighbourhood', 'NN') (',', ',') ('this', 'DT') ('truth', 'NN') ('is', 'VBZ') ('so', 'RB') ('well', 'RB') ('fixed', 'VBN') ('in', 'IN') ('the', 'DT') ('minds', 'NNS') ('of', 'IN') ('the', 'DT') ('surrounding', 'VBG') ('families', 'NNS') (',', ',') ('that', 'IN') ('he', 'PRP') ('is', 'VBZ') ('considered', 'VBN') ('as', 'IN') ('the', 'DT') ('rightful', 'JJ') ('property', 'NN') ('of', 'IN') ('some', 'DT') ('one', 'CD') ('or', 'CC') ('other', 'JJ') ('of', 'IN') ('their', 'PRP$') ('daughters', 'NNS') ('.', '.')

# %% [markdown]
# We print out all the nouns, indicated by:
# NN 	    Noun, singular or mass
# NNP 	Proper noun, singular
# NNS 	Noun, plural
# NNPS 	Proper noun, plural

# %%
for word,pos in wordpos:
         if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
             print(word)
# Out:
# truth
# man
# possession
# fortune
# want
# wife
# feelings
# views
# man
# neighbourhood
# truth
# minds
# families
# property
# daughters

# %% [markdown]
# Now we use a larger amount of text. This line of code gives us the names of the available texts

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# We choose one of them to work with

# %%
emma = nltk.text.Text(nltk.corpus.gutenberg.words('austen-emma.txt'))

# %% [markdown]
# Now we try generating concordances for some individual words

# %%
emma.concordance("man")
# Out:
# Displaying 25 of 235 matches:
# ss for her friend . Mr . Weston was a man of unexceptionable character , easy f
# of mind or body , he was a much older man in ways than in years ; and though ev
# s required support . He was a nervous man , easily depressed ; fond of every bo
# ood - humoured , pleasant , excellent man , that he thoroughly deserves a good
# cessary . Mr . Knightley , a sensible man about seven or eight - and - thirty ,
#  " A straightforward , open - hearted man like Weston , and a rational , unaffe
# " " Mr . Elton is a very pretty young man , to be sure , and a very good young
#  , to be sure , and a very good young man , and I have a great regard for him .
# use his own wife . Depend upon it , a man of six or seven - and - twenty can ta
# s ' marriage , he was rather a poorer man than at first , and with a child to m
# hrough . He had never been an unhappy man ; his own temper had secured him from
# nd report of him as a very fine young man had made Highbury feel a sort of prid
# d a very favourable idea of the young man ; and such a pleasing attention was a
# ry was an intelligent , gentlemanlike man , whose frequent visits were one of t
# ightley ; and by Mr . Elton , a young man living alone without liking it , the
# ing something or other , was a single man ; that there was no young Mrs . Marti
#  " Mr . Martin , I suppose , is not a man of information beyond the line of his
# uestion was -- " What sort of looking man is Mr . Martin ?" " Oh ! not handsome
# of his being a very respectable young man . I know , indeed , that he is so , a
# ry comfortably . They have no indoors man , else they do not want for any thing
# alarming symptoms of love . The young man had been the first admirer , but she
# , and he looked like a sensible young man , but his person had no other advanta
#  But Mr . Knightley is so very fine a man !" " Mr . Knightley ' s air is so rem
# ce . But Mr . Weston is almost an old man . Mr . Weston must be between forty a
# just as it should be , for a thriving man . What has he to do with books ? And

# %%
emma.concordance("woman")
# Out:
# Displaying 25 of 131 matches:
# ce had been supplied by an excellent woman as governess , who had fallen little
# Weston , and a rational , unaffected woman like Miss Taylor , may be safely lef
# ways longed for -- enough to marry a woman as portionless even as Miss Taylor ,
# l a well - judging and truly amiable woman could be , and must give him the ple
# on of it . The aunt was a capricious woman , and governed her husband entirely
#  . She felt herself a most fortunate woman ; and she had lived long enough to k
#  uncommon degree of popularity for a woman neither young , handsome , rich , no
# s possible . And yet she was a happy woman , and a woman whom no one named with
# nd yet she was a happy woman , and a woman whom no one named without good - wil
# . She was a plain , motherly kind of woman , who had worked hard in her youth ,
# could meet with a good sort of young woman in the same rank as his own , with a
#  he marries a very ignorant , vulgar woman , certainly I had better not visit h
# ing young man , a young man whom any woman not fastidious might like . He was r
# can be a good judge of the comfort a woman feels in the society of one of her o
# mith . She is not the superior young woman which Emma ' s friend ought to be .
# s , and yet it is not the style of a woman ; no , certainly , it is too strong
# d concise ; not diffuse enough for a woman . No doubt he is a sensible man , an
# a general rule , Harriet , that if a woman _doubts_ as to whether she should ac
# e friend . We will not be parted . A woman is not to marry a man merely because
# d hands she will turn out a valuable woman ." " I am glad you think so ; and th
# ays incomprehensible to a man that a woman should ever refuse an offer of marri
# f marriage . A man always imagines a woman to be ready for any body who asks he
# too much real feeling to address any woman on the haphazard of selfish passion
# d such temper , the highest claims a woman could possess ." " Upon my word , Em
# lf , ever to marry , she is the very woman for you . And is she , at seventeen

# %%
emma.concordance("gentleman")
# Out:
# Displaying 25 of 35 matches:
# re can be no doubt of your being a gentleman ' s daughter , and you must suppor
# Knightley . But he is not the only gentleman you have been lately used to . Wha
# tion was most suitable , quite the gentleman himself , and without low connexio
# "-- unclosing a pretty sketch of a gentleman in small size , whole - length --"
# tion it would not have disgraced a gentleman ; the language , though plain , wa
# ied to a respectable , intelligent gentleman - farmer !" " As to the circumstan
# ly be a doubt that her father is a gentleman -- and a gentleman of fortune .--
# her father is a gentleman -- and a gentleman of fortune .-- Her allowance is ve
# ement or comfort .-- That she is a gentleman ' s daughter , is indubitable to m
#  gentlemen are ; and nothing but a gentleman in education and manner has any ch
#  , " Oh ! dear , yes ," before the gentleman joined them . The wants and suffer
# . Mr . John Knightley was a tall , gentleman - like , and very clever man ; ris
# modern days indeed have rendered a gentleman ' s carriage perfectly complete .
# countenance was necessary for each gentleman as they walked into Mrs . Weston '
#  of her other complaint before the gentleman ' s return . She went to Mrs . God
# was _very_ _well_ _married_ , to a gentleman in a _great_ _way_ , near Bristol
# u should do ," said she ; " like a gentleman .-- I am quite glad to see you ."
#  have discerned me to be more of a gentleman than usual .-- You might not have
# ligence passed between her and the gentleman on first glancing towards Miss Fai
# is friend . Knightley is quite the gentleman . I like him very much . Decidedly
# uch . Decidedly , I think , a very gentleman - like man ." Happily , it was now
# tley !-- and discover that he is a gentleman ! A little upstart , vulgar being
#  discover that Mr . Knightley is a gentleman ! I doubt whether he will return t
# a smile at her . " I never saw any gentleman ' s handwriting "-- Emma began , l
# k Churchill writes one of the best gentleman ' s hands I ever saw ." " I do not

# %% [markdown]
# Generate ngrams for the words which came from the original tokenized text

# %%
from nltk.util import ngrams
[' '.join(grams) for grams in ngrams(words,4)]
# Out:
# ['It is a truth',
#  'is a truth universally',
#  'a truth universally acknowledged',
#  'truth universally acknowledged ,',
#  'universally acknowledged , that',
#  'acknowledged , that a',
#  ', that a single',
#  'that a single man',
#  'a single man in',
#  'single man in possession',
#  'man in possession of',
#  'in possession of a',
#  'possession of a good',
#  'of a good fortune',
#  'a good fortune must',
#  'good fortune must be',
#  'fortune must be in',
#  'must be in want',
#  'be in want of',
#  'in want of a',
#  'want of a wife',
#  'of a wife .',
#  'a wife . However',
#  'wife . However little',
#  '. However little known',
#  'However little known the',
#  'little known the feelings',
#  'known the feelings or',
#  'the feelings or views',
#  'feelings or views of',
#  'or views of such',
#  'views of such a',
#  'of such a man',
#  'such a man may',
#  'a man may be',
#  'man may be on',
#  'may be on his',
#  'be on his first',
#  'on his first entering',
#  'his first entering a',
#  'first entering a neighbourhood',
#  'entering a neighbourhood ,',
#  'a neighbourhood , this',
#  'neighbourhood , this truth',
#  ', this truth is',
#  'this truth is so',
#  'truth is so well',
#  'is so well fixed',
#  'so well fixed in',
#  'well fixed in the',
#  'fixed in the minds',
#  'in the minds of',
#  'the minds of the',
#  'minds of the surrounding',
#  'of the surrounding families',
#  'the surrounding families ,',
#  'surrounding families , that',
#  'families , that he',
#  ', that he is',
#  'that he is considered',
#  'he is considered as',
#  'is considered as the',
#  'considered as the rightful',
#  'as the rightful property',
#  'the rightful property of',
#  'rightful property of some',
#  'property of some one',
#  'of some one or',
#  'some one or other',
#  'one or other of',
#  'or other of their',
#  'other of their daughters',
#  'of their daughters .']

# %% [markdown]
# Now do this for the text in emma, and show the most common. Try ngrams of 6, 7, 8.

# %%
words = [word.lower() for word in emma if word.isalpha()]
ngrams = nltk.ngrams(words,8)
freqdist = nltk.FreqDist(ngrams)
freqdist.most_common()
# Out:
# [(('behold', 'him', 'there', 'the', 'monarch', 'of', 'the', 'seas'), 3),
#  (('was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of'), 2),
#  (('the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'a'), 2),
#  (('there', 'was', 'nothing', 'to', 'be', 'done', 'for', 'harriet'), 2),
#  (('i', 'have', 'no', 'doubt', 'of', 'his', 'being', 'a'), 2),
#  (('there', 'can', 'be', 'no', 'doubt', 'of', 'your', 'being'), 2),
#  (('the', 'shape', 'of', 'the', 'eye', 'and', 'the', 'lines'), 2),
#  (('shape', 'of', 'the', 'eye', 'and', 'the', 'lines', 'about'), 2),
#  (('of', 'the', 'eye', 'and', 'the', 'lines', 'about', 'the'), 2),
#  (('the', 'eye', 'and', 'the', 'lines', 'about', 'the', 'mouth'), 2),
#  (('you', 'have', 'been', 'no', 'friend', 'to', 'harriet', 'smith'), 2),
#  (('my', 'first', 'displays', 'the', 'wealth', 'and', 'pomp', 'of'), 2),
#  (('first', 'displays', 'the', 'wealth', 'and', 'pomp', 'of', 'kings'), 2),
#  (('displays', 'the', 'wealth', 'and', 'pomp', 'of', 'kings', 'lords'), 2),
#  (('the', 'wealth', 'and', 'pomp', 'of', 'kings', 'lords', 'of'), 2),
#  (('wealth', 'and', 'pomp', 'of', 'kings', 'lords', 'of', 'the'), 2),
#  (('and', 'pomp', 'of', 'kings', 'lords', 'of', 'the', 'earth'), 2),
#  (('pomp', 'of', 'kings', 'lords', 'of', 'the', 'earth', 'their'), 2),
#  (('of', 'kings', 'lords', 'of', 'the', 'earth', 'their', 'luxury'), 2),
#  (('kings', 'lords', 'of', 'the', 'earth', 'their', 'luxury', 'and'), 2),
#  (('lords', 'of', 'the', 'earth', 'their', 'luxury', 'and', 'ease'), 2),
#  (('another', 'view', 'of', 'man', 'my', 'second', 'brings', 'behold'), 2),
#  (('view', 'of', 'man', 'my', 'second', 'brings', 'behold', 'him'), 2),
#  (('of', 'man', 'my', 'second', 'brings', 'behold', 'him', 'there'), 2),
#  (('man', 'my', 'second', 'brings', 'behold', 'him', 'there', 'the'), 2),
#  (('my', 'second', 'brings', 'behold', 'him', 'there', 'the', 'monarch'), 2),
#  (('second', 'brings', 'behold', 'him', 'there', 'the', 'monarch', 'of'), 2),
#  (('brings', 'behold', 'him', 'there', 'the', 'monarch', 'of', 'the'), 2),
#  (('what', 'reverse', 'we', 'have', 'man', 's', 'boasted', 'power'), 2),
#  (('reverse', 'we', 'have', 'man', 's', 'boasted', 'power', 'and'), 2),
#  (('we', 'have', 'man', 's', 'boasted', 'power', 'and', 'freedom'), 2),
#  (('have', 'man', 's', 'boasted', 'power', 'and', 'freedom', 'all'), 2),
#  (('man', 's', 'boasted', 'power', 'and', 'freedom', 'all', 'are'), 2),
#  (('s', 'boasted', 'power', 'and', 'freedom', 'all', 'are', 'flown'), 2),
#  (('boasted', 'power', 'and', 'freedom', 'all', 'are', 'flown', 'lord'), 2),
#  (('power', 'and', 'freedom', 'all', 'are', 'flown', 'lord', 'of'), 2),
#  (('and', 'freedom', 'all', 'are', 'flown', 'lord', 'of', 'the'), 2),
#  (('freedom', 'all', 'are', 'flown', 'lord', 'of', 'the', 'earth'), 2),
#  (('all', 'are', 'flown', 'lord', 'of', 'the', 'earth', 'and'), 2),
#  (('are', 'flown', 'lord', 'of', 'the', 'earth', 'and', 'sea'), 2),
#  (('flown', 'lord', 'of', 'the', 'earth', 'and', 'sea', 'he'), 2),
#  (('lord', 'of', 'the', 'earth', 'and', 'sea', 'he', 'bends'), 2),
#  (('of', 'the', 'earth', 'and', 'sea', 'he', 'bends', 'a'), 2),
#  (('the', 'earth', 'and', 'sea', 'he', 'bends', 'a', 'slave'), 2),
#  (('earth', 'and', 'sea', 'he', 'bends', 'a', 'slave', 'and'), 2),
#  (('and', 'sea', 'he', 'bends', 'a', 'slave', 'and', 'woman'), 2),
#  (('sea', 'he', 'bends', 'a', 'slave', 'and', 'woman', 'lovely'), 2),
#  (('he', 'bends', 'a', 'slave', 'and', 'woman', 'lovely', 'woman'), 2),
#  (('bends', 'a', 'slave', 'and', 'woman', 'lovely', 'woman', 'reigns'), 2),
#  (('a', 'slave', 'and', 'woman', 'lovely', 'woman', 'reigns', 'alone'), 2),
#  (('thy', 'ready', 'wit', 'the', 'word', 'will', 'soon', 'supply'), 2),
#  (('may', 'its', 'approval', 'beam', 'in', 'that', 'soft', 'eye'), 2),
#  (('i', 'should', 'not', 'wonder', 'if', 'it', 'were', 'to'), 2),
#  (('he', 'has', 'not', 'time', 'to', 'take', 'care', 'of'), 2),
#  (('has', 'not', 'time', 'to', 'take', 'care', 'of', 'himself'), 2),
#  (('how', 'd', 'ye', 'do', 'how', 'd', 'ye', 'do'), 2),
#  (('all', 'young', 'people', 'would', 'have', 'their', 'little', 'whims'), 2),
#  (('you', 'play', 'quite', 'as', 'well', 'as', 'she', 'does'), 2),
#  (('how', 'is', 'mr', 'woodhouse', 'i', 'am', 'so', 'glad'), 2),
#  (('i', 'can', 'fasten', 'the', 'rivet', 'i', 'like', 'a'), 2),
#  (('can', 'fasten', 'the', 'rivet', 'i', 'like', 'a', 'job'), 2),
#  (('fasten', 'the', 'rivet', 'i', 'like', 'a', 'job', 'of'), 2),
#  (('you', 'and', 'miss', 'smith', 'and', 'miss', 'fairfax', 'will'), 2),
#  (('and', 'miss', 'smith', 'and', 'miss', 'fairfax', 'will', 'be'), 2),
#  (('miss', 'smith', 'and', 'miss', 'fairfax', 'will', 'be', 'three'), 2),
#  (('smith', 'and', 'miss', 'fairfax', 'will', 'be', 'three', 'and'), 2),
#  (('and', 'miss', 'fairfax', 'will', 'be', 'three', 'and', 'the'), 2),
#  (('miss', 'fairfax', 'will', 'be', 'three', 'and', 'the', 'two'), 2),
#  (('fairfax', 'will', 'be', 'three', 'and', 'the', 'two', 'miss'), 2),
#  (('will', 'be', 'three', 'and', 'the', 'two', 'miss', 'coxes'), 2),
#  (('be', 'three', 'and', 'the', 'two', 'miss', 'coxes', 'five'), 2),
#  (('how', 'do', 'you', 'do', 'very', 'well', 'i', 'thank'), 2),
#  (('do', 'you', 'do', 'very', 'well', 'i', 'thank', 'you'), 2),
#  (('but', 'my', 'dancing', 'days', 'are', 'over', 'mrs', 'weston'), 2),
#  (('ladies', 'and', 'gentlemen', 'i', 'am', 'ordered', 'by', 'miss'), 2),
#  (('and', 'gentlemen', 'i', 'am', 'ordered', 'by', 'miss', 'woodhouse'), 2),
#  (('i', 'will', 'tell', 'you', 'truths', 'while', 'i', 'can'), 2),
#  (('say', 'you', 'are', 'laid', 'down', 'upon', 'the', 'bed'), 2),
#  (('emma', 'by', 'jane', 'austen', 'volume', 'i', 'chapter', 'i'), 1),
#  (('by', 'jane', 'austen', 'volume', 'i', 'chapter', 'i', 'emma'), 1),
#  (('jane', 'austen', 'volume', 'i', 'chapter', 'i', 'emma', 'woodhouse'), 1),
#  (('austen', 'volume', 'i', 'chapter', 'i', 'emma', 'woodhouse', 'handsome'),
#   1),
#  (('volume', 'i', 'chapter', 'i', 'emma', 'woodhouse', 'handsome', 'clever'),
#   1),
#  (('i', 'chapter', 'i', 'emma', 'woodhouse', 'handsome', 'clever', 'and'), 1),
#  (('chapter', 'i', 'emma', 'woodhouse', 'handsome', 'clever', 'and', 'rich'),
#   1),
#  (('i', 'emma', 'woodhouse', 'handsome', 'clever', 'and', 'rich', 'with'), 1),
#  (('emma', 'woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'a'), 1),
#  (('woodhouse',
#    'handsome',
#    'clever',
#    'and',
#    'rich',
#    'with',
#    'a',
#    'comfortable'),
#   1),
#  (('handsome', 'clever', 'and', 'rich', 'with', 'a', 'comfortable', 'home'),
#   1),
#  (('clever', 'and', 'rich', 'with', 'a', 'comfortable', 'home', 'and'), 1),
#  (('and', 'rich', 'with', 'a', 'comfortable', 'home', 'and', 'happy'), 1),
#  (('rich', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition'),
#   1),
#  (('with',
#    'a',
#    'comfortable',
#    'home',
#    'and',
#    'happy',
#    'disposition',
#    'seemed'),
#   1),
#  (('a', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'to'),
#   1),
#  (('comfortable',
#    'home',
#    'and',
#    'happy',
#    'disposition',
#    'seemed',
#    'to',
#    'unite'),
#   1),
#  (('home', 'and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some'), 1),
#  (('and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of'), 1),
#  (('happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the'), 1),
#  (('disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best'), 1),
#  (('seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings'), 1),
#  (('to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of'), 1),
#  (('unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence'), 1),
#  (('some', 'of', 'the', 'best', 'blessings', 'of', 'existence', 'and'), 1),
#  (('of', 'the', 'best', 'blessings', 'of', 'existence', 'and', 'had'), 1),
#  (('the', 'best', 'blessings', 'of', 'existence', 'and', 'had', 'lived'), 1),
#  (('best', 'blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly'),
#   1),
#  (('blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty'),
#   1),
#  (('of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one'), 1),
#  (('existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years'), 1),
#  (('and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in'), 1),
#  (('had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the'), 1),
#  (('lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the', 'world'), 1),
#  (('nearly', 'twenty', 'one', 'years', 'in', 'the', 'world', 'with'), 1),
#  (('twenty', 'one', 'years', 'in', 'the', 'world', 'with', 'very'), 1),
#  (('one', 'years', 'in', 'the', 'world', 'with', 'very', 'little'), 1),
#  (('years', 'in', 'the', 'world', 'with', 'very', 'little', 'to'), 1),
#  (('in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress'), 1),
#  (('the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or'), 1),
#  (('world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex'), 1),
#  (('with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her'), 1),
#  (('very', 'little', 'to', 'distress', 'or', 'vex', 'her', 'she'), 1),
#  (('little', 'to', 'distress', 'or', 'vex', 'her', 'she', 'was'), 1),
#  (('to', 'distress', 'or', 'vex', 'her', 'she', 'was', 'the'), 1),
#  (('distress', 'or', 'vex', 'her', 'she', 'was', 'the', 'youngest'), 1),
#  (('or', 'vex', 'her', 'she', 'was', 'the', 'youngest', 'of'), 1),
#  (('vex', 'her', 'she', 'was', 'the', 'youngest', 'of', 'the'), 1),
#  (('her', 'she', 'was', 'the', 'youngest', 'of', 'the', 'two'), 1),
#  (('she', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters'), 1),
#  (('youngest', 'of', 'the', 'two', 'daughters', 'of', 'a', 'most'), 1),
#  (('of', 'the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate'), 1),
#  (('the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate', 'indulgent'),
#   1),
#  (('two',
#    'daughters',
#    'of',
#    'a',
#    'most',
#    'affectionate',
#    'indulgent',
#    'father'),
#   1),
#  (('daughters',
#    'of',
#    'a',
#    'most',
#    'affectionate',
#    'indulgent',
#    'father',
#    'and'),
#   1),
#  (('of', 'a', 'most', 'affectionate', 'indulgent', 'father', 'and', 'had'), 1),
#  (('a', 'most', 'affectionate', 'indulgent', 'father', 'and', 'had', 'in'), 1),
#  (('most',
#    'affectionate',
#    'indulgent',
#    'father',
#    'and',
#    'had',
#    'in',
#    'consequence'),
#   1),
#  (('affectionate',
#    'indulgent',
#    'father',
#    'and',
#    'had',
#    'in',
#    'consequence',
#    'of'),
#   1),
#  (('indulgent', 'father', 'and', 'had', 'in', 'consequence', 'of', 'her'), 1),
#  (('father', 'and', 'had', 'in', 'consequence', 'of', 'her', 'sister'), 1),
#  (('and', 'had', 'in', 'consequence', 'of', 'her', 'sister', 's'), 1),
#  (('had', 'in', 'consequence', 'of', 'her', 'sister', 's', 'marriage'), 1),
#  (('in', 'consequence', 'of', 'her', 'sister', 's', 'marriage', 'been'), 1),
#  (('consequence', 'of', 'her', 'sister', 's', 'marriage', 'been', 'mistress'),
#   1),
#  (('of', 'her', 'sister', 's', 'marriage', 'been', 'mistress', 'of'), 1),
#  (('her', 'sister', 's', 'marriage', 'been', 'mistress', 'of', 'his'), 1),
#  (('sister', 's', 'marriage', 'been', 'mistress', 'of', 'his', 'house'), 1),
#  (('s', 'marriage', 'been', 'mistress', 'of', 'his', 'house', 'from'), 1),
#  (('marriage', 'been', 'mistress', 'of', 'his', 'house', 'from', 'a'), 1),
#  (('been', 'mistress', 'of', 'his', 'house', 'from', 'a', 'very'), 1),
#  (('mistress', 'of', 'his', 'house', 'from', 'a', 'very', 'early'), 1),
#  (('of', 'his', 'house', 'from', 'a', 'very', 'early', 'period'), 1),
#  (('his', 'house', 'from', 'a', 'very', 'early', 'period', 'her'), 1),
#  (('house', 'from', 'a', 'very', 'early', 'period', 'her', 'mother'), 1),
#  (('from', 'a', 'very', 'early', 'period', 'her', 'mother', 'had'), 1),
#  (('a', 'very', 'early', 'period', 'her', 'mother', 'had', 'died'), 1),
#  (('very', 'early', 'period', 'her', 'mother', 'had', 'died', 'too'), 1),
#  (('early', 'period', 'her', 'mother', 'had', 'died', 'too', 'long'), 1),
#  (('period', 'her', 'mother', 'had', 'died', 'too', 'long', 'ago'), 1),
#  (('her', 'mother', 'had', 'died', 'too', 'long', 'ago', 'for'), 1),
#  (('mother', 'had', 'died', 'too', 'long', 'ago', 'for', 'her'), 1),
#  (('had', 'died', 'too', 'long', 'ago', 'for', 'her', 'to'), 1),
#  (('died', 'too', 'long', 'ago', 'for', 'her', 'to', 'have'), 1),
#  (('too', 'long', 'ago', 'for', 'her', 'to', 'have', 'more'), 1),
#  (('long', 'ago', 'for', 'her', 'to', 'have', 'more', 'than'), 1),
#  (('ago', 'for', 'her', 'to', 'have', 'more', 'than', 'an'), 1),
#  (('for', 'her', 'to', 'have', 'more', 'than', 'an', 'indistinct'), 1),
#  (('her', 'to', 'have', 'more', 'than', 'an', 'indistinct', 'remembrance'), 1),
#  (('to', 'have', 'more', 'than', 'an', 'indistinct', 'remembrance', 'of'), 1),
#  (('have', 'more', 'than', 'an', 'indistinct', 'remembrance', 'of', 'her'), 1),
#  (('more', 'than', 'an', 'indistinct', 'remembrance', 'of', 'her', 'caresses'),
#   1),
#  (('than', 'an', 'indistinct', 'remembrance', 'of', 'her', 'caresses', 'and'),
#   1),
#  (('an', 'indistinct', 'remembrance', 'of', 'her', 'caresses', 'and', 'her'),
#   1),
#  (('indistinct',
#    'remembrance',
#    'of',
#    'her',
#    'caresses',
#    'and',
#    'her',
#    'place'),
#   1),
#  (('remembrance', 'of', 'her', 'caresses', 'and', 'her', 'place', 'had'), 1),
#  (('of', 'her', 'caresses', 'and', 'her', 'place', 'had', 'been'), 1),
#  (('her', 'caresses', 'and', 'her', 'place', 'had', 'been', 'supplied'), 1),
#  (('caresses', 'and', 'her', 'place', 'had', 'been', 'supplied', 'by'), 1),
#  (('and', 'her', 'place', 'had', 'been', 'supplied', 'by', 'an'), 1),
#  (('her', 'place', 'had', 'been', 'supplied', 'by', 'an', 'excellent'), 1),
#  (('place', 'had', 'been', 'supplied', 'by', 'an', 'excellent', 'woman'), 1),
#  (('had', 'been', 'supplied', 'by', 'an', 'excellent', 'woman', 'as'), 1),
#  (('been', 'supplied', 'by', 'an', 'excellent', 'woman', 'as', 'governess'),
#   1),
#  (('supplied', 'by', 'an', 'excellent', 'woman', 'as', 'governess', 'who'), 1),
#  (('by', 'an', 'excellent', 'woman', 'as', 'governess', 'who', 'had'), 1),
#  (('an', 'excellent', 'woman', 'as', 'governess', 'who', 'had', 'fallen'), 1),
#  (('excellent', 'woman', 'as', 'governess', 'who', 'had', 'fallen', 'little'),
#   1),
#  (('woman', 'as', 'governess', 'who', 'had', 'fallen', 'little', 'short'), 1),
#  (('as', 'governess', 'who', 'had', 'fallen', 'little', 'short', 'of'), 1),
#  (('governess', 'who', 'had', 'fallen', 'little', 'short', 'of', 'a'), 1),
#  (('who', 'had', 'fallen', 'little', 'short', 'of', 'a', 'mother'), 1),
#  (('had', 'fallen', 'little', 'short', 'of', 'a', 'mother', 'in'), 1),
#  (('fallen', 'little', 'short', 'of', 'a', 'mother', 'in', 'affection'), 1),
#  (('little', 'short', 'of', 'a', 'mother', 'in', 'affection', 'sixteen'), 1),
#  (('short', 'of', 'a', 'mother', 'in', 'affection', 'sixteen', 'years'), 1),
#  (('of', 'a', 'mother', 'in', 'affection', 'sixteen', 'years', 'had'), 1),
#  (('a', 'mother', 'in', 'affection', 'sixteen', 'years', 'had', 'miss'), 1),
#  (('mother', 'in', 'affection', 'sixteen', 'years', 'had', 'miss', 'taylor'),
#   1),
#  (('in', 'affection', 'sixteen', 'years', 'had', 'miss', 'taylor', 'been'), 1),
#  (('affection', 'sixteen', 'years', 'had', 'miss', 'taylor', 'been', 'in'), 1),
#  (('sixteen', 'years', 'had', 'miss', 'taylor', 'been', 'in', 'mr'), 1),
#  (('years', 'had', 'miss', 'taylor', 'been', 'in', 'mr', 'woodhouse'), 1),
#  (('had', 'miss', 'taylor', 'been', 'in', 'mr', 'woodhouse', 's'), 1),
#  (('miss', 'taylor', 'been', 'in', 'mr', 'woodhouse', 's', 'family'), 1),
#  (('taylor', 'been', 'in', 'mr', 'woodhouse', 's', 'family', 'less'), 1),
#  (('been', 'in', 'mr', 'woodhouse', 's', 'family', 'less', 'as'), 1),
#  (('in', 'mr', 'woodhouse', 's', 'family', 'less', 'as', 'a'), 1),
#  (('mr', 'woodhouse', 's', 'family', 'less', 'as', 'a', 'governess'), 1),
#  (('woodhouse', 's', 'family', 'less', 'as', 'a', 'governess', 'than'), 1),
#  (('s', 'family', 'less', 'as', 'a', 'governess', 'than', 'a'), 1),
#  (('family', 'less', 'as', 'a', 'governess', 'than', 'a', 'friend'), 1),
#  (('less', 'as', 'a', 'governess', 'than', 'a', 'friend', 'very'), 1),
#  (('as', 'a', 'governess', 'than', 'a', 'friend', 'very', 'fond'), 1),
#  (('a', 'governess', 'than', 'a', 'friend', 'very', 'fond', 'of'), 1),
#  (('governess', 'than', 'a', 'friend', 'very', 'fond', 'of', 'both'), 1),
#  (('than', 'a', 'friend', 'very', 'fond', 'of', 'both', 'daughters'), 1),
#  (('a', 'friend', 'very', 'fond', 'of', 'both', 'daughters', 'but'), 1),
#  (('friend', 'very', 'fond', 'of', 'both', 'daughters', 'but', 'particularly'),
#   1),
#  (('very', 'fond', 'of', 'both', 'daughters', 'but', 'particularly', 'of'), 1),
#  (('fond', 'of', 'both', 'daughters', 'but', 'particularly', 'of', 'emma'), 1),
#  (('of', 'both', 'daughters', 'but', 'particularly', 'of', 'emma', 'between'),
#   1),
#  (('both', 'daughters', 'but', 'particularly', 'of', 'emma', 'between', 'it'),
#   1),
#  (('daughters', 'but', 'particularly', 'of', 'emma', 'between', 'it', 'was'),
#   1),
#  (('but', 'particularly', 'of', 'emma', 'between', 'it', 'was', 'more'), 1),
#  (('particularly', 'of', 'emma', 'between', 'it', 'was', 'more', 'the'), 1),
#  (('of', 'emma', 'between', 'it', 'was', 'more', 'the', 'intimacy'), 1),
#  (('emma', 'between', 'it', 'was', 'more', 'the', 'intimacy', 'of'), 1),
#  (('between', 'it', 'was', 'more', 'the', 'intimacy', 'of', 'sisters'), 1),
#  (('it', 'was', 'more', 'the', 'intimacy', 'of', 'sisters', 'even'), 1),
#  (('was', 'more', 'the', 'intimacy', 'of', 'sisters', 'even', 'before'), 1),
#  (('more', 'the', 'intimacy', 'of', 'sisters', 'even', 'before', 'miss'), 1),
#  (('the', 'intimacy', 'of', 'sisters', 'even', 'before', 'miss', 'taylor'), 1),
#  (('intimacy', 'of', 'sisters', 'even', 'before', 'miss', 'taylor', 'had'), 1),
#  (('of', 'sisters', 'even', 'before', 'miss', 'taylor', 'had', 'ceased'), 1),
#  (('sisters', 'even', 'before', 'miss', 'taylor', 'had', 'ceased', 'to'), 1),
#  (('even', 'before', 'miss', 'taylor', 'had', 'ceased', 'to', 'hold'), 1),
#  (('before', 'miss', 'taylor', 'had', 'ceased', 'to', 'hold', 'the'), 1),
#  (('miss', 'taylor', 'had', 'ceased', 'to', 'hold', 'the', 'nominal'), 1),
#  (('taylor', 'had', 'ceased', 'to', 'hold', 'the', 'nominal', 'office'), 1),
#  (('had', 'ceased', 'to', 'hold', 'the', 'nominal', 'office', 'of'), 1),
#  (('ceased', 'to', 'hold', 'the', 'nominal', 'office', 'of', 'governess'), 1),
#  (('to', 'hold', 'the', 'nominal', 'office', 'of', 'governess', 'the'), 1),
#  (('hold', 'the', 'nominal', 'office', 'of', 'governess', 'the', 'mildness'),
#   1),
#  (('the', 'nominal', 'office', 'of', 'governess', 'the', 'mildness', 'of'), 1),
#  (('nominal', 'office', 'of', 'governess', 'the', 'mildness', 'of', 'her'), 1),
#  (('office', 'of', 'governess', 'the', 'mildness', 'of', 'her', 'temper'), 1),
#  (('of', 'governess', 'the', 'mildness', 'of', 'her', 'temper', 'had'), 1),
#  (('governess', 'the', 'mildness', 'of', 'her', 'temper', 'had', 'hardly'), 1),
#  (('the', 'mildness', 'of', 'her', 'temper', 'had', 'hardly', 'allowed'), 1),
#  (('mildness', 'of', 'her', 'temper', 'had', 'hardly', 'allowed', 'her'), 1),
#  (('of', 'her', 'temper', 'had', 'hardly', 'allowed', 'her', 'to'), 1),
#  (('her', 'temper', 'had', 'hardly', 'allowed', 'her', 'to', 'impose'), 1),
#  (('temper', 'had', 'hardly', 'allowed', 'her', 'to', 'impose', 'any'), 1),
#  (('had', 'hardly', 'allowed', 'her', 'to', 'impose', 'any', 'restraint'), 1),
#  (('hardly', 'allowed', 'her', 'to', 'impose', 'any', 'restraint', 'and'), 1),
#  (('allowed', 'her', 'to', 'impose', 'any', 'restraint', 'and', 'the'), 1),
#  (('her', 'to', 'impose', 'any', 'restraint', 'and', 'the', 'shadow'), 1),
#  (('to', 'impose', 'any', 'restraint', 'and', 'the', 'shadow', 'of'), 1),
#  (('impose', 'any', 'restraint', 'and', 'the', 'shadow', 'of', 'authority'),
#   1),
#  (('any', 'restraint', 'and', 'the', 'shadow', 'of', 'authority', 'being'), 1),
#  (('restraint', 'and', 'the', 'shadow', 'of', 'authority', 'being', 'now'), 1),
#  (('and', 'the', 'shadow', 'of', 'authority', 'being', 'now', 'long'), 1),
#  (('the', 'shadow', 'of', 'authority', 'being', 'now', 'long', 'passed'), 1),
#  (('shadow', 'of', 'authority', 'being', 'now', 'long', 'passed', 'away'), 1),
#  (('of', 'authority', 'being', 'now', 'long', 'passed', 'away', 'they'), 1),
#  (('authority', 'being', 'now', 'long', 'passed', 'away', 'they', 'had'), 1),
#  (('being', 'now', 'long', 'passed', 'away', 'they', 'had', 'been'), 1),
#  (('now', 'long', 'passed', 'away', 'they', 'had', 'been', 'living'), 1),
#  (('long', 'passed', 'away', 'they', 'had', 'been', 'living', 'together'), 1),
#  (('passed', 'away', 'they', 'had', 'been', 'living', 'together', 'as'), 1),
#  (('away', 'they', 'had', 'been', 'living', 'together', 'as', 'friend'), 1),
#  (('they', 'had', 'been', 'living', 'together', 'as', 'friend', 'and'), 1),
#  (('had', 'been', 'living', 'together', 'as', 'friend', 'and', 'friend'), 1),
#  (('been', 'living', 'together', 'as', 'friend', 'and', 'friend', 'very'), 1),
#  (('living', 'together', 'as', 'friend', 'and', 'friend', 'very', 'mutually'),
#   1),
#  (('together',
#    'as',
#    'friend',
#    'and',
#    'friend',
#    'very',
#    'mutually',
#    'attached'),
#   1),
#  (('as', 'friend', 'and', 'friend', 'very', 'mutually', 'attached', 'and'), 1),
#  (('friend', 'and', 'friend', 'very', 'mutually', 'attached', 'and', 'emma'),
#   1),
#  (('and', 'friend', 'very', 'mutually', 'attached', 'and', 'emma', 'doing'),
#   1),
#  (('friend', 'very', 'mutually', 'attached', 'and', 'emma', 'doing', 'just'),
#   1),
#  (('very', 'mutually', 'attached', 'and', 'emma', 'doing', 'just', 'what'), 1),
#  (('mutually', 'attached', 'and', 'emma', 'doing', 'just', 'what', 'she'), 1),
#  (('attached', 'and', 'emma', 'doing', 'just', 'what', 'she', 'liked'), 1),
#  (('and', 'emma', 'doing', 'just', 'what', 'she', 'liked', 'highly'), 1),
#  (('emma', 'doing', 'just', 'what', 'she', 'liked', 'highly', 'esteeming'), 1),
#  (('doing', 'just', 'what', 'she', 'liked', 'highly', 'esteeming', 'miss'), 1),
#  (('just', 'what', 'she', 'liked', 'highly', 'esteeming', 'miss', 'taylor'),
#   1),
#  (('what', 'she', 'liked', 'highly', 'esteeming', 'miss', 'taylor', 's'), 1),
#  (('she', 'liked', 'highly', 'esteeming', 'miss', 'taylor', 's', 'judgment'),
#   1),
#  (('liked', 'highly', 'esteeming', 'miss', 'taylor', 's', 'judgment', 'but'),
#   1),
#  (('highly',
#    'esteeming',
#    'miss',
#    'taylor',
#    's',
#    'judgment',
#    'but',
#    'directed'),
#   1),
#  (('esteeming',
#    'miss',
#    'taylor',
#    's',
#    'judgment',
#    'but',
#    'directed',
#    'chiefly'),
#   1),
#  (('miss', 'taylor', 's', 'judgment', 'but', 'directed', 'chiefly', 'by'), 1),
#  (('taylor', 's', 'judgment', 'but', 'directed', 'chiefly', 'by', 'her'), 1),
#  (('s', 'judgment', 'but', 'directed', 'chiefly', 'by', 'her', 'own'), 1),
#  (('judgment', 'but', 'directed', 'chiefly', 'by', 'her', 'own', 'the'), 1),
#  (('but', 'directed', 'chiefly', 'by', 'her', 'own', 'the', 'real'), 1),
#  (('directed', 'chiefly', 'by', 'her', 'own', 'the', 'real', 'evils'), 1),
#  (('chiefly', 'by', 'her', 'own', 'the', 'real', 'evils', 'indeed'), 1),
#  (('by', 'her', 'own', 'the', 'real', 'evils', 'indeed', 'of'), 1),
#  (('her', 'own', 'the', 'real', 'evils', 'indeed', 'of', 'emma'), 1),
#  (('own', 'the', 'real', 'evils', 'indeed', 'of', 'emma', 's'), 1),
#  (('the', 'real', 'evils', 'indeed', 'of', 'emma', 's', 'situation'), 1),
#  (('real', 'evils', 'indeed', 'of', 'emma', 's', 'situation', 'were'), 1),
#  (('evils', 'indeed', 'of', 'emma', 's', 'situation', 'were', 'the'), 1),
#  (('indeed', 'of', 'emma', 's', 'situation', 'were', 'the', 'power'), 1),
#  (('of', 'emma', 's', 'situation', 'were', 'the', 'power', 'of'), 1),
#  (('emma', 's', 'situation', 'were', 'the', 'power', 'of', 'having'), 1),
#  (('s', 'situation', 'were', 'the', 'power', 'of', 'having', 'rather'), 1),
#  (('situation', 'were', 'the', 'power', 'of', 'having', 'rather', 'too'), 1),
#  (('were', 'the', 'power', 'of', 'having', 'rather', 'too', 'much'), 1),
#  (('the', 'power', 'of', 'having', 'rather', 'too', 'much', 'her'), 1),
#  (('power', 'of', 'having', 'rather', 'too', 'much', 'her', 'own'), 1),
#  (('of', 'having', 'rather', 'too', 'much', 'her', 'own', 'way'), 1),
#  (('having', 'rather', 'too', 'much', 'her', 'own', 'way', 'and'), 1),
#  (('rather', 'too', 'much', 'her', 'own', 'way', 'and', 'a'), 1),
#  (('too', 'much', 'her', 'own', 'way', 'and', 'a', 'disposition'), 1),
#  (('much', 'her', 'own', 'way', 'and', 'a', 'disposition', 'to'), 1),
#  (('her', 'own', 'way', 'and', 'a', 'disposition', 'to', 'think'), 1),
#  (('own', 'way', 'and', 'a', 'disposition', 'to', 'think', 'a'), 1),
#  (('way', 'and', 'a', 'disposition', 'to', 'think', 'a', 'little'), 1),
#  (('and', 'a', 'disposition', 'to', 'think', 'a', 'little', 'too'), 1),
#  (('a', 'disposition', 'to', 'think', 'a', 'little', 'too', 'well'), 1),
#  (('disposition', 'to', 'think', 'a', 'little', 'too', 'well', 'of'), 1),
#  (('to', 'think', 'a', 'little', 'too', 'well', 'of', 'herself'), 1),
#  (('think', 'a', 'little', 'too', 'well', 'of', 'herself', 'these'), 1),
#  (('a', 'little', 'too', 'well', 'of', 'herself', 'these', 'were'), 1),
#  (('little', 'too', 'well', 'of', 'herself', 'these', 'were', 'the'), 1),
#  (('too', 'well', 'of', 'herself', 'these', 'were', 'the', 'disadvantages'),
#   1),
#  (('well', 'of', 'herself', 'these', 'were', 'the', 'disadvantages', 'which'),
#   1),
#  (('of',
#    'herself',
#    'these',
#    'were',
#    'the',
#    'disadvantages',
#    'which',
#    'threatened'),
#   1),
#  (('herself',
#    'these',
#    'were',
#    'the',
#    'disadvantages',
#    'which',
#    'threatened',
#    'alloy'),
#   1),
#  (('these',
#    'were',
#    'the',
#    'disadvantages',
#    'which',
#    'threatened',
#    'alloy',
#    'to'),
#   1),
#  (('were',
#    'the',
#    'disadvantages',
#    'which',
#    'threatened',
#    'alloy',
#    'to',
#    'her'),
#   1),
#  (('the',
#    'disadvantages',
#    'which',
#    'threatened',
#    'alloy',
#    'to',
#    'her',
#    'many'),
#   1),
#  (('disadvantages',
#    'which',
#    'threatened',
#    'alloy',
#    'to',
#    'her',
#    'many',
#    'enjoyments'),
#   1),
#  (('which', 'threatened', 'alloy', 'to', 'her', 'many', 'enjoyments', 'the'),
#   1),
#  (('threatened', 'alloy', 'to', 'her', 'many', 'enjoyments', 'the', 'danger'),
#   1),
#  (('alloy', 'to', 'her', 'many', 'enjoyments', 'the', 'danger', 'however'), 1),
#  (('to', 'her', 'many', 'enjoyments', 'the', 'danger', 'however', 'was'), 1),
#  (('her', 'many', 'enjoyments', 'the', 'danger', 'however', 'was', 'at'), 1),
#  (('many', 'enjoyments', 'the', 'danger', 'however', 'was', 'at', 'present'),
#   1),
#  (('enjoyments', 'the', 'danger', 'however', 'was', 'at', 'present', 'so'), 1),
#  (('the', 'danger', 'however', 'was', 'at', 'present', 'so', 'unperceived'),
#   1),
#  (('danger', 'however', 'was', 'at', 'present', 'so', 'unperceived', 'that'),
#   1),
#  (('however', 'was', 'at', 'present', 'so', 'unperceived', 'that', 'they'), 1),
#  (('was', 'at', 'present', 'so', 'unperceived', 'that', 'they', 'did'), 1),
#  (('at', 'present', 'so', 'unperceived', 'that', 'they', 'did', 'not'), 1),
#  (('present', 'so', 'unperceived', 'that', 'they', 'did', 'not', 'by'), 1),
#  (('so', 'unperceived', 'that', 'they', 'did', 'not', 'by', 'any'), 1),
#  (('unperceived', 'that', 'they', 'did', 'not', 'by', 'any', 'means'), 1),
#  (('that', 'they', 'did', 'not', 'by', 'any', 'means', 'rank'), 1),
#  (('they', 'did', 'not', 'by', 'any', 'means', 'rank', 'as'), 1),
#  (('did', 'not', 'by', 'any', 'means', 'rank', 'as', 'misfortunes'), 1),
#  (('not', 'by', 'any', 'means', 'rank', 'as', 'misfortunes', 'with'), 1),
#  (('by', 'any', 'means', 'rank', 'as', 'misfortunes', 'with', 'her'), 1),
#  (('any', 'means', 'rank', 'as', 'misfortunes', 'with', 'her', 'sorrow'), 1),
#  (('means', 'rank', 'as', 'misfortunes', 'with', 'her', 'sorrow', 'came'), 1),
#  (('rank', 'as', 'misfortunes', 'with', 'her', 'sorrow', 'came', 'a'), 1),
#  (('as', 'misfortunes', 'with', 'her', 'sorrow', 'came', 'a', 'gentle'), 1),
#  (('misfortunes', 'with', 'her', 'sorrow', 'came', 'a', 'gentle', 'sorrow'),
#   1),
#  (('with', 'her', 'sorrow', 'came', 'a', 'gentle', 'sorrow', 'but'), 1),
#  (('her', 'sorrow', 'came', 'a', 'gentle', 'sorrow', 'but', 'not'), 1),
#  (('sorrow', 'came', 'a', 'gentle', 'sorrow', 'but', 'not', 'at'), 1),
#  (('came', 'a', 'gentle', 'sorrow', 'but', 'not', 'at', 'all'), 1),
#  (('a', 'gentle', 'sorrow', 'but', 'not', 'at', 'all', 'in'), 1),
#  (('gentle', 'sorrow', 'but', 'not', 'at', 'all', 'in', 'the'), 1),
#  (('sorrow', 'but', 'not', 'at', 'all', 'in', 'the', 'shape'), 1),
#  (('but', 'not', 'at', 'all', 'in', 'the', 'shape', 'of'), 1),
#  (('not', 'at', 'all', 'in', 'the', 'shape', 'of', 'any'), 1),
#  (('at', 'all', 'in', 'the', 'shape', 'of', 'any', 'disagreeable'), 1),
#  (('all', 'in', 'the', 'shape', 'of', 'any', 'disagreeable', 'consciousness'),
#   1),
#  (('in', 'the', 'shape', 'of', 'any', 'disagreeable', 'consciousness', 'miss'),
#   1),
#  (('the',
#    'shape',
#    'of',
#    'any',
#    'disagreeable',
#    'consciousness',
#    'miss',
#    'taylor'),
#   1),
#  (('shape',
#    'of',
#    'any',
#    'disagreeable',
#    'consciousness',
#    'miss',
#    'taylor',
#    'married'),
#   1),
#  (('of',
#    'any',
#    'disagreeable',
#    'consciousness',
#    'miss',
#    'taylor',
#    'married',
#    'it'),
#   1),
#  (('any',
#    'disagreeable',
#    'consciousness',
#    'miss',
#    'taylor',
#    'married',
#    'it',
#    'was'),
#   1),
#  (('disagreeable',
#    'consciousness',
#    'miss',
#    'taylor',
#    'married',
#    'it',
#    'was',
#    'miss'),
#   1),
#  (('consciousness',
#    'miss',
#    'taylor',
#    'married',
#    'it',
#    'was',
#    'miss',
#    'taylor'),
#   1),
#  (('miss', 'taylor', 'married', 'it', 'was', 'miss', 'taylor', 's'), 1),
#  (('taylor', 'married', 'it', 'was', 'miss', 'taylor', 's', 'loss'), 1),
#  (('married', 'it', 'was', 'miss', 'taylor', 's', 'loss', 'which'), 1),
#  (('it', 'was', 'miss', 'taylor', 's', 'loss', 'which', 'first'), 1),
#  (('was', 'miss', 'taylor', 's', 'loss', 'which', 'first', 'brought'), 1),
#  (('miss', 'taylor', 's', 'loss', 'which', 'first', 'brought', 'grief'), 1),
#  (('taylor', 's', 'loss', 'which', 'first', 'brought', 'grief', 'it'), 1),
#  (('s', 'loss', 'which', 'first', 'brought', 'grief', 'it', 'was'), 1),
#  (('loss', 'which', 'first', 'brought', 'grief', 'it', 'was', 'on'), 1),
#  (('which', 'first', 'brought', 'grief', 'it', 'was', 'on', 'the'), 1),
#  (('first', 'brought', 'grief', 'it', 'was', 'on', 'the', 'wedding'), 1),
#  (('brought', 'grief', 'it', 'was', 'on', 'the', 'wedding', 'day'), 1),
#  (('grief', 'it', 'was', 'on', 'the', 'wedding', 'day', 'of'), 1),
#  (('it', 'was', 'on', 'the', 'wedding', 'day', 'of', 'this'), 1),
#  (('was', 'on', 'the', 'wedding', 'day', 'of', 'this', 'beloved'), 1),
#  (('on', 'the', 'wedding', 'day', 'of', 'this', 'beloved', 'friend'), 1),
#  (('the', 'wedding', 'day', 'of', 'this', 'beloved', 'friend', 'that'), 1),
#  (('wedding', 'day', 'of', 'this', 'beloved', 'friend', 'that', 'emma'), 1),
#  (('day', 'of', 'this', 'beloved', 'friend', 'that', 'emma', 'first'), 1),
#  (('of', 'this', 'beloved', 'friend', 'that', 'emma', 'first', 'sat'), 1),
#  (('this', 'beloved', 'friend', 'that', 'emma', 'first', 'sat', 'in'), 1),
#  (('beloved', 'friend', 'that', 'emma', 'first', 'sat', 'in', 'mournful'), 1),
#  (('friend', 'that', 'emma', 'first', 'sat', 'in', 'mournful', 'thought'), 1),
#  (('that', 'emma', 'first', 'sat', 'in', 'mournful', 'thought', 'of'), 1),
#  (('emma', 'first', 'sat', 'in', 'mournful', 'thought', 'of', 'any'), 1),
#  (('first', 'sat', 'in', 'mournful', 'thought', 'of', 'any', 'continuance'),
#   1),
#  (('sat', 'in', 'mournful', 'thought', 'of', 'any', 'continuance', 'the'), 1),
#  (('in', 'mournful', 'thought', 'of', 'any', 'continuance', 'the', 'wedding'),
#   1),
#  (('mournful',
#    'thought',
#    'of',
#    'any',
#    'continuance',
#    'the',
#    'wedding',
#    'over'),
#   1),
#  (('thought', 'of', 'any', 'continuance', 'the', 'wedding', 'over', 'and'), 1),
#  (('of', 'any', 'continuance', 'the', 'wedding', 'over', 'and', 'the'), 1),
#  (('any', 'continuance', 'the', 'wedding', 'over', 'and', 'the', 'bride'), 1),
#  (('continuance', 'the', 'wedding', 'over', 'and', 'the', 'bride', 'people'),
#   1),
#  (('the', 'wedding', 'over', 'and', 'the', 'bride', 'people', 'gone'), 1),
#  (('wedding', 'over', 'and', 'the', 'bride', 'people', 'gone', 'her'), 1),
#  (('over', 'and', 'the', 'bride', 'people', 'gone', 'her', 'father'), 1),
#  (('and', 'the', 'bride', 'people', 'gone', 'her', 'father', 'and'), 1),
#  (('the', 'bride', 'people', 'gone', 'her', 'father', 'and', 'herself'), 1),
#  (('bride', 'people', 'gone', 'her', 'father', 'and', 'herself', 'were'), 1),
#  (('people', 'gone', 'her', 'father', 'and', 'herself', 'were', 'left'), 1),
#  (('gone', 'her', 'father', 'and', 'herself', 'were', 'left', 'to'), 1),
#  (('her', 'father', 'and', 'herself', 'were', 'left', 'to', 'dine'), 1),
#  (('father', 'and', 'herself', 'were', 'left', 'to', 'dine', 'together'), 1),
#  (('and', 'herself', 'were', 'left', 'to', 'dine', 'together', 'with'), 1),
#  (('herself', 'were', 'left', 'to', 'dine', 'together', 'with', 'no'), 1),
#  (('were', 'left', 'to', 'dine', 'together', 'with', 'no', 'prospect'), 1),
#  (('left', 'to', 'dine', 'together', 'with', 'no', 'prospect', 'of'), 1),
#  (('to', 'dine', 'together', 'with', 'no', 'prospect', 'of', 'a'), 1),
#  (('dine', 'together', 'with', 'no', 'prospect', 'of', 'a', 'third'), 1),
#  (('together', 'with', 'no', 'prospect', 'of', 'a', 'third', 'to'), 1),
#  (('with', 'no', 'prospect', 'of', 'a', 'third', 'to', 'cheer'), 1),
#  (('no', 'prospect', 'of', 'a', 'third', 'to', 'cheer', 'a'), 1),
#  (('prospect', 'of', 'a', 'third', 'to', 'cheer', 'a', 'long'), 1),
#  (('of', 'a', 'third', 'to', 'cheer', 'a', 'long', 'evening'), 1),
#  (('a', 'third', 'to', 'cheer', 'a', 'long', 'evening', 'her'), 1),
#  (('third', 'to', 'cheer', 'a', 'long', 'evening', 'her', 'father'), 1),
#  (('to', 'cheer', 'a', 'long', 'evening', 'her', 'father', 'composed'), 1),
#  (('cheer', 'a', 'long', 'evening', 'her', 'father', 'composed', 'himself'),
#   1),
#  (('a', 'long', 'evening', 'her', 'father', 'composed', 'himself', 'to'), 1),
#  (('long', 'evening', 'her', 'father', 'composed', 'himself', 'to', 'sleep'),
#   1),
#  (('evening', 'her', 'father', 'composed', 'himself', 'to', 'sleep', 'after'),
#   1),
#  (('her', 'father', 'composed', 'himself', 'to', 'sleep', 'after', 'dinner'),
#   1),
#  (('father', 'composed', 'himself', 'to', 'sleep', 'after', 'dinner', 'as'),
#   1),
#  (('composed', 'himself', 'to', 'sleep', 'after', 'dinner', 'as', 'usual'), 1),
#  (('himself', 'to', 'sleep', 'after', 'dinner', 'as', 'usual', 'and'), 1),
#  (('to', 'sleep', 'after', 'dinner', 'as', 'usual', 'and', 'she'), 1),
#  (('sleep', 'after', 'dinner', 'as', 'usual', 'and', 'she', 'had'), 1),
#  (('after', 'dinner', 'as', 'usual', 'and', 'she', 'had', 'then'), 1),
#  (('dinner', 'as', 'usual', 'and', 'she', 'had', 'then', 'only'), 1),
#  (('as', 'usual', 'and', 'she', 'had', 'then', 'only', 'to'), 1),
#  (('usual', 'and', 'she', 'had', 'then', 'only', 'to', 'sit'), 1),
#  (('and', 'she', 'had', 'then', 'only', 'to', 'sit', 'and'), 1),
#  (('she', 'had', 'then', 'only', 'to', 'sit', 'and', 'think'), 1),
#  (('had', 'then', 'only', 'to', 'sit', 'and', 'think', 'of'), 1),
#  (('then', 'only', 'to', 'sit', 'and', 'think', 'of', 'what'), 1),
#  (('only', 'to', 'sit', 'and', 'think', 'of', 'what', 'she'), 1),
#  (('to', 'sit', 'and', 'think', 'of', 'what', 'she', 'had'), 1),
#  (('sit', 'and', 'think', 'of', 'what', 'she', 'had', 'lost'), 1),
#  (('and', 'think', 'of', 'what', 'she', 'had', 'lost', 'the'), 1),
#  (('think', 'of', 'what', 'she', 'had', 'lost', 'the', 'event'), 1),
#  (('of', 'what', 'she', 'had', 'lost', 'the', 'event', 'had'), 1),
#  (('what', 'she', 'had', 'lost', 'the', 'event', 'had', 'every'), 1),
#  (('she', 'had', 'lost', 'the', 'event', 'had', 'every', 'promise'), 1),
#  (('had', 'lost', 'the', 'event', 'had', 'every', 'promise', 'of'), 1),
#  (('lost', 'the', 'event', 'had', 'every', 'promise', 'of', 'happiness'), 1),
#  (('the', 'event', 'had', 'every', 'promise', 'of', 'happiness', 'for'), 1),
#  (('event', 'had', 'every', 'promise', 'of', 'happiness', 'for', 'her'), 1),
#  (('had', 'every', 'promise', 'of', 'happiness', 'for', 'her', 'friend'), 1),
#  (('every', 'promise', 'of', 'happiness', 'for', 'her', 'friend', 'mr'), 1),
#  (('promise', 'of', 'happiness', 'for', 'her', 'friend', 'mr', 'weston'), 1),
#  (('of', 'happiness', 'for', 'her', 'friend', 'mr', 'weston', 'was'), 1),
#  (('happiness', 'for', 'her', 'friend', 'mr', 'weston', 'was', 'a'), 1),
#  (('for', 'her', 'friend', 'mr', 'weston', 'was', 'a', 'man'), 1),
#  (('her', 'friend', 'mr', 'weston', 'was', 'a', 'man', 'of'), 1),
#  (('friend', 'mr', 'weston', 'was', 'a', 'man', 'of', 'unexceptionable'), 1),
#  (('mr', 'weston', 'was', 'a', 'man', 'of', 'unexceptionable', 'character'),
#   1),
#  (('weston', 'was', 'a', 'man', 'of', 'unexceptionable', 'character', 'easy'),
#   1),
#  (('was', 'a', 'man', 'of', 'unexceptionable', 'character', 'easy', 'fortune'),
#   1),
#  (('a',
#    'man',
#    'of',
#    'unexceptionable',
#    'character',
#    'easy',
#    'fortune',
#    'suitable'),
#   1),
#  (('man',
#    'of',
#    'unexceptionable',
#    'character',
#    'easy',
#    'fortune',
#    'suitable',
#    'age'),
#   1),
#  (('of',
#    'unexceptionable',
#    'character',
#    'easy',
#    'fortune',
#    'suitable',
#    'age',
#    'and'),
#   1),
#  (('unexceptionable',
#    'character',
#    'easy',
#    'fortune',
#    'suitable',
#    'age',
#    'and',
#    'pleasant'),
#   1),
#  (('character',
#    'easy',
#    'fortune',
#    'suitable',
#    'age',
#    'and',
#    'pleasant',
#    'manners'),
#   1),
#  (('easy', 'fortune', 'suitable', 'age', 'and', 'pleasant', 'manners', 'and'),
#   1),
#  (('fortune', 'suitable', 'age', 'and', 'pleasant', 'manners', 'and', 'there'),
#   1),
#  (('suitable', 'age', 'and', 'pleasant', 'manners', 'and', 'there', 'was'), 1),
#  (('age', 'and', 'pleasant', 'manners', 'and', 'there', 'was', 'some'), 1),
#  (('and',
#    'pleasant',
#    'manners',
#    'and',
#    'there',
#    'was',
#    'some',
#    'satisfaction'),
#   1),
#  (('pleasant', 'manners', 'and', 'there', 'was', 'some', 'satisfaction', 'in'),
#   1),
#  (('manners',
#    'and',
#    'there',
#    'was',
#    'some',
#    'satisfaction',
#    'in',
#    'considering'),
#   1),
#  (('and', 'there', 'was', 'some', 'satisfaction', 'in', 'considering', 'with'),
#   1),
#  (('there',
#    'was',
#    'some',
#    'satisfaction',
#    'in',
#    'considering',
#    'with',
#    'what'),
#   1),
#  (('was', 'some', 'satisfaction', 'in', 'considering', 'with', 'what', 'self'),
#   1),
#  (('some',
#    'satisfaction',
#    'in',
#    'considering',
#    'with',
#    'what',
#    'self',
#    'denying'),
#   1),
#  (('satisfaction',
#    'in',
#    'considering',
#    'with',
#    'what',
#    'self',
#    'denying',
#    'generous'),
#   1),
#  (('in',
#    'considering',
#    'with',
#    'what',
#    'self',
#    'denying',
#    'generous',
#    'friendship'),
#   1),
#  (('considering',
#    'with',
#    'what',
#    'self',
#    'denying',
#    'generous',
#    'friendship',
#    'she'),
#   1),
#  (('with', 'what', 'self', 'denying', 'generous', 'friendship', 'she', 'had'),
#   1),
#  (('what',
#    'self',
#    'denying',
#    'generous',
#    'friendship',
#    'she',
#    'had',
#    'always'),
#   1),
#  (('self',
#    'denying',
#    'generous',
#    'friendship',
#    'she',
#    'had',
#    'always',
#    'wished'),
#   1),
#  (('denying',
#    'generous',
#    'friendship',
#    'she',
#    'had',
#    'always',
#    'wished',
#    'and'),
#   1),
#  (('generous',
#    'friendship',
#    'she',
#    'had',
#    'always',
#    'wished',
#    'and',
#    'promoted'),
#   1),
#  (('friendship', 'she', 'had', 'always', 'wished', 'and', 'promoted', 'the'),
#   1),
#  (('she', 'had', 'always', 'wished', 'and', 'promoted', 'the', 'match'), 1),
#  (('had', 'always', 'wished', 'and', 'promoted', 'the', 'match', 'but'), 1),
#  (('always', 'wished', 'and', 'promoted', 'the', 'match', 'but', 'it'), 1),
#  (('wished', 'and', 'promoted', 'the', 'match', 'but', 'it', 'was'), 1),
#  (('and', 'promoted', 'the', 'match', 'but', 'it', 'was', 'a'), 1),
#  (('promoted', 'the', 'match', 'but', 'it', 'was', 'a', 'black'), 1),
#  (('the', 'match', 'but', 'it', 'was', 'a', 'black', 'morning'), 1),
#  (('match', 'but', 'it', 'was', 'a', 'black', 'morning', 's'), 1),
#  (('but', 'it', 'was', 'a', 'black', 'morning', 's', 'work'), 1),
#  (('it', 'was', 'a', 'black', 'morning', 's', 'work', 'for'), 1),
#  (('was', 'a', 'black', 'morning', 's', 'work', 'for', 'her'), 1),
#  (('a', 'black', 'morning', 's', 'work', 'for', 'her', 'the'), 1),
#  (('black', 'morning', 's', 'work', 'for', 'her', 'the', 'want'), 1),
#  (('morning', 's', 'work', 'for', 'her', 'the', 'want', 'of'), 1),
#  (('s', 'work', 'for', 'her', 'the', 'want', 'of', 'miss'), 1),
#  (('work', 'for', 'her', 'the', 'want', 'of', 'miss', 'taylor'), 1),
#  (('for', 'her', 'the', 'want', 'of', 'miss', 'taylor', 'would'), 1),
#  (('her', 'the', 'want', 'of', 'miss', 'taylor', 'would', 'be'), 1),
#  (('the', 'want', 'of', 'miss', 'taylor', 'would', 'be', 'felt'), 1),
#  (('want', 'of', 'miss', 'taylor', 'would', 'be', 'felt', 'every'), 1),
#  (('of', 'miss', 'taylor', 'would', 'be', 'felt', 'every', 'hour'), 1),
#  (('miss', 'taylor', 'would', 'be', 'felt', 'every', 'hour', 'of'), 1),
#  (('taylor', 'would', 'be', 'felt', 'every', 'hour', 'of', 'every'), 1),
#  (('would', 'be', 'felt', 'every', 'hour', 'of', 'every', 'day'), 1),
#  (('be', 'felt', 'every', 'hour', 'of', 'every', 'day', 'she'), 1),
#  (('felt', 'every', 'hour', 'of', 'every', 'day', 'she', 'recalled'), 1),
#  (('every', 'hour', 'of', 'every', 'day', 'she', 'recalled', 'her'), 1),
#  (('hour', 'of', 'every', 'day', 'she', 'recalled', 'her', 'past'), 1),
#  (('of', 'every', 'day', 'she', 'recalled', 'her', 'past', 'kindness'), 1),
#  (('every', 'day', 'she', 'recalled', 'her', 'past', 'kindness', 'the'), 1),
#  (('day', 'she', 'recalled', 'her', 'past', 'kindness', 'the', 'kindness'), 1),
#  (('she', 'recalled', 'her', 'past', 'kindness', 'the', 'kindness', 'the'), 1),
#  (('recalled',
#    'her',
#    'past',
#    'kindness',
#    'the',
#    'kindness',
#    'the',
#    'affection'),
#   1),
#  (('her', 'past', 'kindness', 'the', 'kindness', 'the', 'affection', 'of'), 1),
#  (('past', 'kindness', 'the', 'kindness', 'the', 'affection', 'of', 'sixteen'),
#   1),
#  (('kindness',
#    'the',
#    'kindness',
#    'the',
#    'affection',
#    'of',
#    'sixteen',
#    'years'),
#   1),
#  (('the', 'kindness', 'the', 'affection', 'of', 'sixteen', 'years', 'how'), 1),
#  (('kindness', 'the', 'affection', 'of', 'sixteen', 'years', 'how', 'she'), 1),
#  (('the', 'affection', 'of', 'sixteen', 'years', 'how', 'she', 'had'), 1),
#  (('affection', 'of', 'sixteen', 'years', 'how', 'she', 'had', 'taught'), 1),
#  (('of', 'sixteen', 'years', 'how', 'she', 'had', 'taught', 'and'), 1),
#  (('sixteen', 'years', 'how', 'she', 'had', 'taught', 'and', 'how'), 1),
#  (('years', 'how', 'she', 'had', 'taught', 'and', 'how', 'she'), 1),
#  (('how', 'she', 'had', 'taught', 'and', 'how', 'she', 'had'), 1),
#  (('she', 'had', 'taught', 'and', 'how', 'she', 'had', 'played'), 1),
#  (('had', 'taught', 'and', 'how', 'she', 'had', 'played', 'with'), 1),
#  (('taught', 'and', 'how', 'she', 'had', 'played', 'with', 'her'), 1),
#  (('and', 'how', 'she', 'had', 'played', 'with', 'her', 'from'), 1),
#  (('how', 'she', 'had', 'played', 'with', 'her', 'from', 'five'), 1),
#  (('she', 'had', 'played', 'with', 'her', 'from', 'five', 'years'), 1),
#  (('had', 'played', 'with', 'her', 'from', 'five', 'years', 'old'), 1),
#  (('played', 'with', 'her', 'from', 'five', 'years', 'old', 'how'), 1),
#  (('with', 'her', 'from', 'five', 'years', 'old', 'how', 'she'), 1),
#  (('her', 'from', 'five', 'years', 'old', 'how', 'she', 'had'), 1),
#  (('from', 'five', 'years', 'old', 'how', 'she', 'had', 'devoted'), 1),
#  (('five', 'years', 'old', 'how', 'she', 'had', 'devoted', 'all'), 1),
#  (('years', 'old', 'how', 'she', 'had', 'devoted', 'all', 'her'), 1),
#  (('old', 'how', 'she', 'had', 'devoted', 'all', 'her', 'powers'), 1),
#  (('how', 'she', 'had', 'devoted', 'all', 'her', 'powers', 'to'), 1),
#  (('she', 'had', 'devoted', 'all', 'her', 'powers', 'to', 'attach'), 1),
#  (('had', 'devoted', 'all', 'her', 'powers', 'to', 'attach', 'and'), 1),
#  (('devoted', 'all', 'her', 'powers', 'to', 'attach', 'and', 'amuse'), 1),
#  (('all', 'her', 'powers', 'to', 'attach', 'and', 'amuse', 'her'), 1),
#  (('her', 'powers', 'to', 'attach', 'and', 'amuse', 'her', 'in'), 1),
#  (('powers', 'to', 'attach', 'and', 'amuse', 'her', 'in', 'health'), 1),
#  (('to', 'attach', 'and', 'amuse', 'her', 'in', 'health', 'and'), 1),
#  (('attach', 'and', 'amuse', 'her', 'in', 'health', 'and', 'how'), 1),
#  (('and', 'amuse', 'her', 'in', 'health', 'and', 'how', 'nursed'), 1),
#  (('amuse', 'her', 'in', 'health', 'and', 'how', 'nursed', 'her'), 1),
#  (('her', 'in', 'health', 'and', 'how', 'nursed', 'her', 'through'), 1),
#  (('in', 'health', 'and', 'how', 'nursed', 'her', 'through', 'the'), 1),
#  (('health', 'and', 'how', 'nursed', 'her', 'through', 'the', 'various'), 1),
#  (('and', 'how', 'nursed', 'her', 'through', 'the', 'various', 'illnesses'),
#   1),
#  (('how', 'nursed', 'her', 'through', 'the', 'various', 'illnesses', 'of'), 1),
#  (('nursed',
#    'her',
#    'through',
#    'the',
#    'various',
#    'illnesses',
#    'of',
#    'childhood'),
#   1),
#  (('her', 'through', 'the', 'various', 'illnesses', 'of', 'childhood', 'a'),
#   1),
#  (('through', 'the', 'various', 'illnesses', 'of', 'childhood', 'a', 'large'),
#   1),
#  (('the', 'various', 'illnesses', 'of', 'childhood', 'a', 'large', 'debt'), 1),
#  (('various', 'illnesses', 'of', 'childhood', 'a', 'large', 'debt', 'of'), 1),
#  (('illnesses', 'of', 'childhood', 'a', 'large', 'debt', 'of', 'gratitude'),
#   1),
#  (('of', 'childhood', 'a', 'large', 'debt', 'of', 'gratitude', 'was'), 1),
#  (('childhood', 'a', 'large', 'debt', 'of', 'gratitude', 'was', 'owing'), 1),
#  (('a', 'large', 'debt', 'of', 'gratitude', 'was', 'owing', 'here'), 1),
#  (('large', 'debt', 'of', 'gratitude', 'was', 'owing', 'here', 'but'), 1),
#  (('debt', 'of', 'gratitude', 'was', 'owing', 'here', 'but', 'the'), 1),
#  (('of', 'gratitude', 'was', 'owing', 'here', 'but', 'the', 'intercourse'), 1),
#  (('gratitude', 'was', 'owing', 'here', 'but', 'the', 'intercourse', 'of'), 1),
#  (('was', 'owing', 'here', 'but', 'the', 'intercourse', 'of', 'the'), 1),
#  (('owing', 'here', 'but', 'the', 'intercourse', 'of', 'the', 'last'), 1),
#  (('here', 'but', 'the', 'intercourse', 'of', 'the', 'last', 'seven'), 1),
#  (('but', 'the', 'intercourse', 'of', 'the', 'last', 'seven', 'years'), 1),
#  (('the', 'intercourse', 'of', 'the', 'last', 'seven', 'years', 'the'), 1),
#  (('intercourse', 'of', 'the', 'last', 'seven', 'years', 'the', 'equal'), 1),
#  (('of', 'the', 'last', 'seven', 'years', 'the', 'equal', 'footing'), 1),
#  (('the', 'last', 'seven', 'years', 'the', 'equal', 'footing', 'and'), 1),
#  (('last', 'seven', 'years', 'the', 'equal', 'footing', 'and', 'perfect'), 1),
#  (('seven', 'years', 'the', 'equal', 'footing', 'and', 'perfect', 'unreserve'),
#   1),
#  (('years', 'the', 'equal', 'footing', 'and', 'perfect', 'unreserve', 'which'),
#   1),
#  (('the', 'equal', 'footing', 'and', 'perfect', 'unreserve', 'which', 'had'),
#   1),
#  (('equal', 'footing', 'and', 'perfect', 'unreserve', 'which', 'had', 'soon'),
#   1),
#  (('footing',
#    'and',
#    'perfect',
#    'unreserve',
#    'which',
#    'had',
#    'soon',
#    'followed'),
#   1),
#  (('and',
#    'perfect',
#    'unreserve',
#    'which',
#    'had',
#    'soon',
#    'followed',
#    'isabella'),
#   1),
#  (('perfect',
#    'unreserve',
#    'which',
#    'had',
#    'soon',
#    'followed',
#    'isabella',
#    's'),
#   1),
#  (('unreserve',
#    'which',
#    'had',
#    'soon',
#    'followed',
#    'isabella',
#    's',
#    'marriage'),
#   1),
#  (('which', 'had', 'soon', 'followed', 'isabella', 's', 'marriage', 'on'), 1),
#  (('had', 'soon', 'followed', 'isabella', 's', 'marriage', 'on', 'their'), 1),
#  (('soon', 'followed', 'isabella', 's', 'marriage', 'on', 'their', 'being'),
#   1),
#  (('followed', 'isabella', 's', 'marriage', 'on', 'their', 'being', 'left'),
#   1),
#  (('isabella', 's', 'marriage', 'on', 'their', 'being', 'left', 'to'), 1),
#  (('s', 'marriage', 'on', 'their', 'being', 'left', 'to', 'each'), 1),
#  (('marriage', 'on', 'their', 'being', 'left', 'to', 'each', 'other'), 1),
#  (('on', 'their', 'being', 'left', 'to', 'each', 'other', 'was'), 1),
#  (('their', 'being', 'left', 'to', 'each', 'other', 'was', 'yet'), 1),
#  (('being', 'left', 'to', 'each', 'other', 'was', 'yet', 'a'), 1),
#  (('left', 'to', 'each', 'other', 'was', 'yet', 'a', 'dearer'), 1),
#  (('to', 'each', 'other', 'was', 'yet', 'a', 'dearer', 'tenderer'), 1),
#  (('each', 'other', 'was', 'yet', 'a', 'dearer', 'tenderer', 'recollection'),
#   1),
#  (('other', 'was', 'yet', 'a', 'dearer', 'tenderer', 'recollection', 'she'),
#   1),
#  (('was', 'yet', 'a', 'dearer', 'tenderer', 'recollection', 'she', 'had'), 1),
# ...
#  (('for', 'having', 'been', 'a', 'valetudinarian', 'all', 'his', 'life'), 1),
#  (('having', 'been', 'a', 'valetudinarian', 'all', 'his', 'life', 'without'),
#   1),
#  (('been', 'a', 'valetudinarian', 'all', 'his', 'life', 'without', 'activity'),
#   1),
#  (('a', 'valetudinarian', 'all', 'his', 'life', 'without', 'activity', 'of'),
#   1),
#  (('valetudinarian',
#    'all',
#    'his',
#    'life',
#    'without',
#    'activity',
#    'of',
#    'mind'),
#   1),
#  (('all', 'his', 'life', 'without', 'activity', 'of', 'mind', 'or'), 1),
#  (('his', 'life', 'without', 'activity', 'of', 'mind', 'or', 'body'), 1),
#  (('life', 'without', 'activity', 'of', 'mind', 'or', 'body', 'he'), 1),
#  (('without', 'activity', 'of', 'mind', 'or', 'body', 'he', 'was'), 1),
#  (('activity', 'of', 'mind', 'or', 'body', 'he', 'was', 'a'), 1),
#  (('of', 'mind', 'or', 'body', 'he', 'was', 'a', 'much'), 1),
#  (('mind', 'or', 'body', 'he', 'was', 'a', 'much', 'older'), 1),
#  (('or', 'body', 'he', 'was', 'a', 'much', 'older', 'man'), 1),
#  (('body', 'he', 'was', 'a', 'much', 'older', 'man', 'in'), 1),
#  (('he', 'was', 'a', 'much', 'older', 'man', 'in', 'ways'), 1),
#  (('was', 'a', 'much', 'older', 'man', 'in', 'ways', 'than'), 1),
#  (('a', 'much', 'older', 'man', 'in', 'ways', 'than', 'in'), 1),
#  (('much', 'older', 'man', 'in', 'ways', 'than', 'in', 'years'), 1),
#  (('older', 'man', 'in', 'ways', 'than', 'in', 'years', 'and'), 1),
#  (('man', 'in', 'ways', 'than', 'in', 'years', 'and', 'though'), 1),
#  (('in', 'ways', 'than', 'in', 'years', 'and', 'though', 'everywhere'), 1),
#  (('ways', 'than', 'in', 'years', 'and', 'though', 'everywhere', 'beloved'),
#   1),
#  (('than', 'in', 'years', 'and', 'though', 'everywhere', 'beloved', 'for'), 1),
#  (('in', 'years', 'and', 'though', 'everywhere', 'beloved', 'for', 'the'), 1),
#  (('years',
#    'and',
#    'though',
#    'everywhere',
#    'beloved',
#    'for',
#    'the',
#    'friendliness'),
#   1),
#  (('and',
#    'though',
#    'everywhere',
#    'beloved',
#    'for',
#    'the',
#    'friendliness',
#    'of'),
#   1),
#  (('though',
#    'everywhere',
#    'beloved',
#    'for',
#    'the',
#    'friendliness',
#    'of',
#    'his'),
#   1),
#  (('everywhere',
#    'beloved',
#    'for',
#    'the',
#    'friendliness',
#    'of',
#    'his',
#    'heart'),
#   1),
#  (('beloved', 'for', 'the', 'friendliness', 'of', 'his', 'heart', 'and'), 1),
#  (('for', 'the', 'friendliness', 'of', 'his', 'heart', 'and', 'his'), 1),
#  (('the', 'friendliness', 'of', 'his', 'heart', 'and', 'his', 'amiable'), 1),
#  (('friendliness', 'of', 'his', 'heart', 'and', 'his', 'amiable', 'temper'),
#   1),
#  (('of', 'his', 'heart', 'and', 'his', 'amiable', 'temper', 'his'), 1),
#  (('his', 'heart', 'and', 'his', 'amiable', 'temper', 'his', 'talents'), 1),
#  (('heart', 'and', 'his', 'amiable', 'temper', 'his', 'talents', 'could'), 1),
#  (('and', 'his', 'amiable', 'temper', 'his', 'talents', 'could', 'not'), 1),
#  (('his', 'amiable', 'temper', 'his', 'talents', 'could', 'not', 'have'), 1),
#  (('amiable',
#    'temper',
#    'his',
#    'talents',
#    'could',
#    'not',
#    'have',
#    'recommended'),
#   1),
#  (('temper', 'his', 'talents', 'could', 'not', 'have', 'recommended', 'him'),
#   1),
#  (('his', 'talents', 'could', 'not', 'have', 'recommended', 'him', 'at'), 1),
#  (('talents', 'could', 'not', 'have', 'recommended', 'him', 'at', 'any'), 1),
#  (('could', 'not', 'have', 'recommended', 'him', 'at', 'any', 'time'), 1),
#  (('not', 'have', 'recommended', 'him', 'at', 'any', 'time', 'her'), 1),
#  (('have', 'recommended', 'him', 'at', 'any', 'time', 'her', 'sister'), 1),
#  (('recommended', 'him', 'at', 'any', 'time', 'her', 'sister', 'though'), 1),
#  (('him', 'at', 'any', 'time', 'her', 'sister', 'though', 'comparatively'), 1),
#  (('at', 'any', 'time', 'her', 'sister', 'though', 'comparatively', 'but'), 1),
#  (('any', 'time', 'her', 'sister', 'though', 'comparatively', 'but', 'little'),
#   1),
#  (('time',
#    'her',
#    'sister',
#    'though',
#    'comparatively',
#    'but',
#    'little',
#    'removed'),
#   1),
#  (('her',
#    'sister',
#    'though',
#    'comparatively',
#    'but',
#    'little',
#    'removed',
#    'by'),
#   1),
#  (('sister',
#    'though',
#    'comparatively',
#    'but',
#    'little',
#    'removed',
#    'by',
#    'matrimony'),
#   1),
#  (('though',
#    'comparatively',
#    'but',
#    'little',
#    'removed',
#    'by',
#    'matrimony',
#    'being'),
#   1),
#  (('comparatively',
#    'but',
#    'little',
#    'removed',
#    'by',
#    'matrimony',
#    'being',
#    'settled'),
#   1),
#  (('but', 'little', 'removed', 'by', 'matrimony', 'being', 'settled', 'in'),
#   1),
#  (('little', 'removed', 'by', 'matrimony', 'being', 'settled', 'in', 'london'),
#   1),
#  (('removed', 'by', 'matrimony', 'being', 'settled', 'in', 'london', 'only'),
#   1),
#  (('by', 'matrimony', 'being', 'settled', 'in', 'london', 'only', 'sixteen'),
#   1),
#  (('matrimony',
#    'being',
#    'settled',
#    'in',
#    'london',
#    'only',
#    'sixteen',
#    'miles'),
#   1),
#  (('being', 'settled', 'in', 'london', 'only', 'sixteen', 'miles', 'off'), 1),
#  (('settled', 'in', 'london', 'only', 'sixteen', 'miles', 'off', 'was'), 1),
#  (('in', 'london', 'only', 'sixteen', 'miles', 'off', 'was', 'much'), 1),
#  (('london', 'only', 'sixteen', 'miles', 'off', 'was', 'much', 'beyond'), 1),
#  (('only', 'sixteen', 'miles', 'off', 'was', 'much', 'beyond', 'her'), 1),
#  (('sixteen', 'miles', 'off', 'was', 'much', 'beyond', 'her', 'daily'), 1),
#  (('miles', 'off', 'was', 'much', 'beyond', 'her', 'daily', 'reach'), 1),
#  (('off', 'was', 'much', 'beyond', 'her', 'daily', 'reach', 'and'), 1),
#  (('was', 'much', 'beyond', 'her', 'daily', 'reach', 'and', 'many'), 1),
#  (('much', 'beyond', 'her', 'daily', 'reach', 'and', 'many', 'a'), 1),
#  (('beyond', 'her', 'daily', 'reach', 'and', 'many', 'a', 'long'), 1),
#  (('her', 'daily', 'reach', 'and', 'many', 'a', 'long', 'october'), 1),
#  (('daily', 'reach', 'and', 'many', 'a', 'long', 'october', 'and'), 1),
#  (('reach', 'and', 'many', 'a', 'long', 'october', 'and', 'november'), 1),
#  (('and', 'many', 'a', 'long', 'october', 'and', 'november', 'evening'), 1),
#  (('many', 'a', 'long', 'october', 'and', 'november', 'evening', 'must'), 1),
#  (('a', 'long', 'october', 'and', 'november', 'evening', 'must', 'be'), 1),
#  (('long', 'october', 'and', 'november', 'evening', 'must', 'be', 'struggled'),
#   1),
#  (('october',
#    'and',
#    'november',
#    'evening',
#    'must',
#    'be',
#    'struggled',
#    'through'),
#   1),
#  (('and', 'november', 'evening', 'must', 'be', 'struggled', 'through', 'at'),
#   1),
#  (('november',
#    'evening',
#    'must',
#    'be',
#    'struggled',
#    'through',
#    'at',
#    'hartfield'),
#   1),
#  (('evening',
#    'must',
#    'be',
#    'struggled',
#    'through',
#    'at',
#    'hartfield',
#    'before'),
#   1),
#  (('must',
#    'be',
#    'struggled',
#    'through',
#    'at',
#    'hartfield',
#    'before',
#    'christmas'),
#   1),
#  (('be',
#    'struggled',
#    'through',
#    'at',
#    'hartfield',
#    'before',
#    'christmas',
#    'brought'),
#   1),
#  (('struggled',
#    'through',
#    'at',
#    'hartfield',
#    'before',
#    'christmas',
#    'brought',
#    'the'),
#   1),
#  (('through',
#    'at',
#    'hartfield',
#    'before',
#    'christmas',
#    'brought',
#    'the',
#    'next'),
#   1),
#  (('at',
#    'hartfield',
#    'before',
#    'christmas',
#    'brought',
#    'the',
#    'next',
#    'visit'),
#   1),
#  (('hartfield',
#    'before',
#    'christmas',
#    'brought',
#    'the',
#    'next',
#    'visit',
#    'from'),
#   1),
#  (('before',
#    'christmas',
#    'brought',
#    'the',
#    'next',
#    'visit',
#    'from',
#    'isabella'),
#   1),
#  (('christmas', 'brought', 'the', 'next', 'visit', 'from', 'isabella', 'and'),
#   1),
#  (('brought', 'the', 'next', 'visit', 'from', 'isabella', 'and', 'her'), 1),
#  (('the', 'next', 'visit', 'from', 'isabella', 'and', 'her', 'husband'), 1),
#  (('next', 'visit', 'from', 'isabella', 'and', 'her', 'husband', 'and'), 1),
#  (('visit', 'from', 'isabella', 'and', 'her', 'husband', 'and', 'their'), 1),
#  (('from', 'isabella', 'and', 'her', 'husband', 'and', 'their', 'little'), 1),
#  (('isabella', 'and', 'her', 'husband', 'and', 'their', 'little', 'children'),
#   1),
#  (('and', 'her', 'husband', 'and', 'their', 'little', 'children', 'to'), 1),
#  (('her', 'husband', 'and', 'their', 'little', 'children', 'to', 'fill'), 1),
#  (('husband', 'and', 'their', 'little', 'children', 'to', 'fill', 'the'), 1),
#  (('and', 'their', 'little', 'children', 'to', 'fill', 'the', 'house'), 1),
#  (('their', 'little', 'children', 'to', 'fill', 'the', 'house', 'and'), 1),
#  (('little', 'children', 'to', 'fill', 'the', 'house', 'and', 'give'), 1),
#  (('children', 'to', 'fill', 'the', 'house', 'and', 'give', 'her'), 1),
#  (('to', 'fill', 'the', 'house', 'and', 'give', 'her', 'pleasant'), 1),
#  (('fill', 'the', 'house', 'and', 'give', 'her', 'pleasant', 'society'), 1),
#  (('the', 'house', 'and', 'give', 'her', 'pleasant', 'society', 'again'), 1),
#  (('house', 'and', 'give', 'her', 'pleasant', 'society', 'again', 'highbury'),
#   1),
#  (('and', 'give', 'her', 'pleasant', 'society', 'again', 'highbury', 'the'),
#   1),
#  (('give', 'her', 'pleasant', 'society', 'again', 'highbury', 'the', 'large'),
#   1),
#  (('her', 'pleasant', 'society', 'again', 'highbury', 'the', 'large', 'and'),
#   1),
#  (('pleasant',
#    'society',
#    'again',
#    'highbury',
#    'the',
#    'large',
#    'and',
#    'populous'),
#   1),
#  (('society',
#    'again',
#    'highbury',
#    'the',
#    'large',
#    'and',
#    'populous',
#    'village'),
#   1),
#  (('again',
#    'highbury',
#    'the',
#    'large',
#    'and',
#    'populous',
#    'village',
#    'almost'),
#   1),
#  (('highbury',
#    'the',
#    'large',
#    'and',
#    'populous',
#    'village',
#    'almost',
#    'amounting'),
#   1),
#  (('the', 'large', 'and', 'populous', 'village', 'almost', 'amounting', 'to'),
#   1),
#  (('large', 'and', 'populous', 'village', 'almost', 'amounting', 'to', 'a'),
#   1),
#  (('and', 'populous', 'village', 'almost', 'amounting', 'to', 'a', 'town'), 1),
#  (('populous', 'village', 'almost', 'amounting', 'to', 'a', 'town', 'to'), 1),
#  (('village', 'almost', 'amounting', 'to', 'a', 'town', 'to', 'which'), 1),
#  (('almost', 'amounting', 'to', 'a', 'town', 'to', 'which', 'hartfield'), 1),
#  (('amounting', 'to', 'a', 'town', 'to', 'which', 'hartfield', 'in'), 1),
#  (('to', 'a', 'town', 'to', 'which', 'hartfield', 'in', 'spite'), 1),
#  (('a', 'town', 'to', 'which', 'hartfield', 'in', 'spite', 'of'), 1),
#  (('town', 'to', 'which', 'hartfield', 'in', 'spite', 'of', 'its'), 1),
#  (('to', 'which', 'hartfield', 'in', 'spite', 'of', 'its', 'separate'), 1),
#  (('which', 'hartfield', 'in', 'spite', 'of', 'its', 'separate', 'lawn'), 1),
#  (('hartfield', 'in', 'spite', 'of', 'its', 'separate', 'lawn', 'and'), 1),
#  (('in', 'spite', 'of', 'its', 'separate', 'lawn', 'and', 'shrubberies'), 1),
#  (('spite', 'of', 'its', 'separate', 'lawn', 'and', 'shrubberies', 'and'), 1),
#  (('of', 'its', 'separate', 'lawn', 'and', 'shrubberies', 'and', 'name'), 1),
#  (('its', 'separate', 'lawn', 'and', 'shrubberies', 'and', 'name', 'did'), 1),
#  (('separate', 'lawn', 'and', 'shrubberies', 'and', 'name', 'did', 'really'),
#   1),
#  (('lawn', 'and', 'shrubberies', 'and', 'name', 'did', 'really', 'belong'), 1),
#  (('and', 'shrubberies', 'and', 'name', 'did', 'really', 'belong', 'afforded'),
#   1),
#  (('shrubberies', 'and', 'name', 'did', 'really', 'belong', 'afforded', 'her'),
#   1),
#  (('and', 'name', 'did', 'really', 'belong', 'afforded', 'her', 'no'), 1),
#  (('name', 'did', 'really', 'belong', 'afforded', 'her', 'no', 'equals'), 1),
#  (('did', 'really', 'belong', 'afforded', 'her', 'no', 'equals', 'the'), 1),
#  (('really', 'belong', 'afforded', 'her', 'no', 'equals', 'the', 'woodhouses'),
#   1),
#  (('belong', 'afforded', 'her', 'no', 'equals', 'the', 'woodhouses', 'were'),
#   1),
#  (('afforded', 'her', 'no', 'equals', 'the', 'woodhouses', 'were', 'first'),
#   1),
#  (('her', 'no', 'equals', 'the', 'woodhouses', 'were', 'first', 'in'), 1),
#  (('no', 'equals', 'the', 'woodhouses', 'were', 'first', 'in', 'consequence'),
#   1),
#  (('equals',
#    'the',
#    'woodhouses',
#    'were',
#    'first',
#    'in',
#    'consequence',
#    'there'),
#   1),
#  (('the', 'woodhouses', 'were', 'first', 'in', 'consequence', 'there', 'all'),
#   1),
#  (('woodhouses',
#    'were',
#    'first',
#    'in',
#    'consequence',
#    'there',
#    'all',
#    'looked'),
#   1),
#  (('were', 'first', 'in', 'consequence', 'there', 'all', 'looked', 'up'), 1),
#  (('first', 'in', 'consequence', 'there', 'all', 'looked', 'up', 'to'), 1),
#  (('in', 'consequence', 'there', 'all', 'looked', 'up', 'to', 'them'), 1),
#  (('consequence', 'there', 'all', 'looked', 'up', 'to', 'them', 'she'), 1),
#  (('there', 'all', 'looked', 'up', 'to', 'them', 'she', 'had'), 1),
#  (('all', 'looked', 'up', 'to', 'them', 'she', 'had', 'many'), 1),
#  (('looked', 'up', 'to', 'them', 'she', 'had', 'many', 'acquaintance'), 1),
#  (('up', 'to', 'them', 'she', 'had', 'many', 'acquaintance', 'in'), 1),
#  (('to', 'them', 'she', 'had', 'many', 'acquaintance', 'in', 'the'), 1),
#  (('them', 'she', 'had', 'many', 'acquaintance', 'in', 'the', 'place'), 1),
#  (('she', 'had', 'many', 'acquaintance', 'in', 'the', 'place', 'for'), 1),
#  (('had', 'many', 'acquaintance', 'in', 'the', 'place', 'for', 'her'), 1),
#  (('many', 'acquaintance', 'in', 'the', 'place', 'for', 'her', 'father'), 1),
#  (('acquaintance', 'in', 'the', 'place', 'for', 'her', 'father', 'was'), 1),
#  (('in', 'the', 'place', 'for', 'her', 'father', 'was', 'universally'), 1),
#  (('the', 'place', 'for', 'her', 'father', 'was', 'universally', 'civil'), 1),
#  (('place', 'for', 'her', 'father', 'was', 'universally', 'civil', 'but'), 1),
#  (('for', 'her', 'father', 'was', 'universally', 'civil', 'but', 'not'), 1),
#  (('her', 'father', 'was', 'universally', 'civil', 'but', 'not', 'one'), 1),
#  (('father', 'was', 'universally', 'civil', 'but', 'not', 'one', 'among'), 1),
#  (('was', 'universally', 'civil', 'but', 'not', 'one', 'among', 'them'), 1),
#  (('universally', 'civil', 'but', 'not', 'one', 'among', 'them', 'who'), 1),
#  (('civil', 'but', 'not', 'one', 'among', 'them', 'who', 'could'), 1),
#  (('but', 'not', 'one', 'among', 'them', 'who', 'could', 'be'), 1),
#  (('not', 'one', 'among', 'them', 'who', 'could', 'be', 'accepted'), 1),
#  (('one', 'among', 'them', 'who', 'could', 'be', 'accepted', 'in'), 1),
#  (('among', 'them', 'who', 'could', 'be', 'accepted', 'in', 'lieu'), 1),
#  (('them', 'who', 'could', 'be', 'accepted', 'in', 'lieu', 'of'), 1),
#  (('who', 'could', 'be', 'accepted', 'in', 'lieu', 'of', 'miss'), 1),
#  (('could', 'be', 'accepted', 'in', 'lieu', 'of', 'miss', 'taylor'), 1),
#  (('be', 'accepted', 'in', 'lieu', 'of', 'miss', 'taylor', 'for'), 1),
#  (('accepted', 'in', 'lieu', 'of', 'miss', 'taylor', 'for', 'even'), 1),
#  (('in', 'lieu', 'of', 'miss', 'taylor', 'for', 'even', 'half'), 1),
#  (('lieu', 'of', 'miss', 'taylor', 'for', 'even', 'half', 'a'), 1),
#  (('of', 'miss', 'taylor', 'for', 'even', 'half', 'a', 'day'), 1),
#  (('miss', 'taylor', 'for', 'even', 'half', 'a', 'day', 'it'), 1),
#  (('taylor', 'for', 'even', 'half', 'a', 'day', 'it', 'was'), 1),
#  (('for', 'even', 'half', 'a', 'day', 'it', 'was', 'a'), 1),
#  (('even', 'half', 'a', 'day', 'it', 'was', 'a', 'melancholy'), 1),
#  (('half', 'a', 'day', 'it', 'was', 'a', 'melancholy', 'change'), 1),
#  (('a', 'day', 'it', 'was', 'a', 'melancholy', 'change', 'and'), 1),
#  (('day', 'it', 'was', 'a', 'melancholy', 'change', 'and', 'emma'), 1),
#  (('it', 'was', 'a', 'melancholy', 'change', 'and', 'emma', 'could'), 1),
#  (('was', 'a', 'melancholy', 'change', 'and', 'emma', 'could', 'not'), 1),
#  (('a', 'melancholy', 'change', 'and', 'emma', 'could', 'not', 'but'), 1),
#  (('melancholy', 'change', 'and', 'emma', 'could', 'not', 'but', 'sigh'), 1),
#  (('change', 'and', 'emma', 'could', 'not', 'but', 'sigh', 'over'), 1),
#  (('and', 'emma', 'could', 'not', 'but', 'sigh', 'over', 'it'), 1),
#  (('emma', 'could', 'not', 'but', 'sigh', 'over', 'it', 'and'), 1),
#  (('could', 'not', 'but', 'sigh', 'over', 'it', 'and', 'wish'), 1),
#  (('not', 'but', 'sigh', 'over', 'it', 'and', 'wish', 'for'), 1),
#  (('but', 'sigh', 'over', 'it', 'and', 'wish', 'for', 'impossible'), 1),
#  (('sigh', 'over', 'it', 'and', 'wish', 'for', 'impossible', 'things'), 1),
#  (('over', 'it', 'and', 'wish', 'for', 'impossible', 'things', 'till'), 1),
#  ...]

# %% [markdown]
# Plot the frequency distribution of words

# %%
dic = nltk.FreqDist(words)
dic.plot(50, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# Do this again, but remove stopwords first

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
dic = nltk.FreqDist(words)
dic.plot(50, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.corpus import gutenberg
from nltk.sentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# In response to Q&A - this is a hint at how nltk can support sentiment analysis, but the example really needs developing a lot further. The sentiment analyser output is Negative, Neutral, Positive and Compound (aggregated score).

# %%
analyzer.polarity_scores("I really love the afternoon cake")
# Out:
# {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.6697}

# %%
analyzer.polarity_scores("I am scared the projector will stop working")
# Out:
# {'neg': 0.505, 'neu': 0.495, 'pos': 0.0, 'compound': -0.6249}

# %%
sents
# Out:
# ['\nIt is a truth universally acknowledged, that a single man in possession of a good fortune must\nbe in want of a wife.',
#  'However little known the feelings or views of such a man may be on his\nfirst entering a neighbourhood, this truth is so well fixed in the minds of the surrounding\nfamilies, that he is considered as the rightful property of some one or other of their daughters.']

# %%
analyzer.polarity_scores(sents[0])
# Out:
# {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.6705}

# %%
analyzer.polarity_scores(sents[1])
# Out:
# {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.6147}

# %% [markdown]
# Let' apply this to some arbitrarily chosen sentences from Emma

# %%
emma_sentences = gutenberg.sents('austen-emma.txt')
print(*emma_sentences[10:12])
# Out:
# ['The', 'danger', ',', 'however', ',', 'was', 'at', 'present', 'so', 'unperceived', ',', 'that', 'they', 'did', 'not', 'by', 'any', 'means', 'rank', 'as', 'misfortunes', 'with', 'her', '.'] ['Sorrow', 'came', '--', 'a', 'gentle', 'sorrow', '--', 'but', 'not', 'at', 'all', 'in', 'the', 'shape', 'of', 'any', 'disagreeable', 'consciousness', '.--', 'Miss', 'Taylor', 'married', '.']

# %%
s10 = ' '.join(emma_sentences[10])
s11 = ' '.join(emma_sentences[11])

# %%
print(s10)
analyzer.polarity_scores(s10)
# Out:
# The danger , however , was at present so unperceived , that they did not by any means rank as misfortunes with her .
# {'neg': 0.152, 'neu': 0.848, 'pos': 0.0, 'compound': -0.5267}

# %%
print(s11)
analyzer.polarity_scores(s11)
# Out:
# Sorrow came -- a gentle sorrow -- but not at all in the shape of any disagreeable consciousness .-- Miss Taylor married .
# {'neg': 0.354, 'neu': 0.576, 'pos': 0.07, 'compound': -0.7845}
